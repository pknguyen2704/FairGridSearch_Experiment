# %% [markdown]
# # Bias Mitigation Experiments - StudentsPerformance

# %%
data_name = 'StudentsPerformance'

# %%
# to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
# tf.disable_eager_execution() # comment out when running TabTransformer models

# %% [markdown]
# ## [1.](#Table-of-Contents) Prepare COMPAS data

# %%
# read in data as pandas data frame
df = pd.read_csv("../data/StudentsPerformance/StudentsPerformance.csv")
# check columns
pd.set_option('display.max_columns', None) # expand all columns
print(df.shape)
df.head()
# Out:
# (1000, 8)
#    gender     race parental level of education         lunch  \
# 0  female  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# data pre-processing
import re
label = 'test preparation course'
protected_attribute = 'gender'
# 1. select features of interest
# 2. encode label and potential protected features 
label_mapping = {'completed': 1, 'none': 0}
# race_mapping = {'group D': 1, 'group C': 0}
sex_mapping = {'female': 1, 'male': 0} # female is the privileged group in this case

# df = df[df.race.isin(race_mapping.keys())] # only include samples with certain race values
# df.race.replace(race_mapping, inplace=True)
df.gender.replace(sex_mapping, inplace=True)
df[label].replace(label_mapping, inplace=True)
df = df.reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# (1000, 8)
#    gender     race parental level of education         lunch  \
# 0       1  group B           bachelor's degree      standard
# 1       1  group C                some college      standard
# 2       1  group B             master's degree      standard
# 3       0  group A          associate's degree  free/reduced
# 4       0  group C                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                        0          72             72             74
# 1                        1          69             90             88
# 2                        0          90             95             93
# 3                        0          47             57             44
# 4                        0          76             78             75

# %%
# flip labels to ensure pos_label = 1, not becoming recidivist

# select descriptive features and target variable
X = df.drop(columns=label, axis=1) # select all features but target feature
y = df[[protected_attribute, label]] # include protected feature in order to AIF360

# %%
df.head(100)
# Out:
#     gender     race parental level of education         lunch  \
# 0        1  group B           bachelor's degree      standard
# 1        1  group C                some college      standard
# 2        1  group B             master's degree      standard
# 3        0  group A          associate's degree  free/reduced
# 4        0  group C                some college      standard
# ..     ...      ...                         ...           ...
# 95       0  group C          associate's degree  free/reduced
# 96       0  group B            some high school      standard
# 97       1  group E                some college      standard
# 98       1  group D                some college  free/reduced
# 99       1  group D           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 0                         0          72             72             74
# 1                         1          69             90             88
# 2                         0          90             95             93
# 3                         0          47             57             44
# 4                         0          76             78             75
# ..                      ...         ...            ...            ...
# 95                        1          78             81             82
# 96                        1          65             66             62
# 97                        1          63             72             70
# 98                        0          58             67             62
# 99                        0          65             67             62
#
# [100 rows x 8 columns]

# %%
# set protected attribute as index
X = X.set_index([protected_attribute], append = True, drop = False)
y = y.set_index([protected_attribute], append = True)

# make y data frames to 1d array to pass modeling, but keep index (protected attribute)
y = pd.Series(y[label], index=y.index)

# %%
X.to_pickle('../data/{}/{}_X'.format(data_name, data_name))
y.to_pickle('../data/{}/{}_y'.format(data_name, data_name))

# %% [markdown]
# ## [2.](#Table-of-Contents) Proposed GridSearch Approach

# %% [markdown]
# The GridSearch Approach includes hyperparameter, threshold, and Bias Mitigation

# %%
from FairGridSearch import *
# %load_ext autoreload
# %autoreload 2
# allow automatic reloading of changes in FairGridSearch file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# None, better
# 'RW', worse
# 'LFR_pre', stuck
# 'LFR_in', stuck
# 'AD', stuck
# 'EGR',better
# 'ROC', better
# 'CEO', better

# %% [markdown]
# ## 3. Case Study: StudentsPerformance

# %%
label = 'test preparation course'
protected_attribute = 'gender'

pos_label = 0
priv_group = 1

cv=10
n_jobs=multiprocessing.cpu_count()-1

# %%
X = pd.read_pickle('../data/{}/{}_X'.format(data_name, data_name))
y = pd.read_pickle('../data/{}/{}_y'.format(data_name, data_name))

# %%
# define desired metric for the use case
ACC_METRIC = 'avg_norm_mcc_score'
FAIR_METRIC = 'abs_avg_ppvd_score'

# %% [markdown]
# ### Logistic Regression

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'C':[1, 10],'solver':['liblinear', 'saga'],'penalty':['l2']}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','LFR_in','AD','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_lr = fair_GridsearchCV(base='LR', param_grid=param_grid, 
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_lr.fit(X=X, y=y)
    
results_lr = clf_lr.output_table
print(clf_lr._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_lr.to_pickle('./{}_results/{}_results_LR'.format(data_name,data_name))
style_table(results_lr)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [01:02<03:06, 62.15s/it]
# {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [01:51<01:49, 54.66s/it]
# {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [02:58<01:00, 60.39s/it]
# {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [03:48<00:00, 57.07s/it]
# base_estimator                                                   LR
# param              {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Bias_Mitigation                                                  RW
# threshold                                                       0.4
# Name: 6, dtype: object
# Time:  3.8193586916666664 min
# <style type="text/css">
# #T_24a69_row0_col0, #T_24a69_row0_col1, #T_24a69_row1_col0, #T_24a69_row1_col1, #T_24a69_row1_col3, #T_24a69_row2_col0, #T_24a69_row2_col1, #T_24a69_row3_col0, #T_24a69_row3_col1, #T_24a69_row4_col0, #T_24a69_row4_col1, #T_24a69_row5_col0, #T_24a69_row5_col1, #T_24a69_row5_col2, #T_24a69_row5_col7, #T_24a69_row6_col0, #T_24a69_row6_col1, #T_24a69_row6_col2, #T_24a69_row6_col3, #T_24a69_row6_col4, #T_24a69_row6_col5, #T_24a69_row6_col6, #T_24a69_row6_col7, #T_24a69_row6_col8, #T_24a69_row6_col9, #T_24a69_row6_col10, #T_24a69_row6_col11, #T_24a69_row6_col12, #T_24a69_row6_col13, #T_24a69_row6_col14, #T_24a69_row6_col15, #T_24a69_row6_col16, #T_24a69_row6_col17, #T_24a69_row7_col0, #T_24a69_row7_col1, #T_24a69_row7_col2, #T_24a69_row7_col7, #T_24a69_row8_col0, #T_24a69_row8_col1, #T_24a69_row8_col2, #T_24a69_row8_col7, #T_24a69_row9_col0, #T_24a69_row9_col1, #T_24a69_row9_col2, #T_24a69_row9_col7, #T_24a69_row10_col0, #T_24a69_row10_col1, #T_24a69_row11_col0, #T_24a69_row11_col1, #T_24a69_row11_col3, #T_24a69_row12_col0, #T_24a69_row12_col1, #T_24a69_row13_col0, #T_24a69_row13_col1, #T_24a69_row14_col0, #T_24a69_row14_col1, #T_24a69_row15_col0, #T_24a69_row15_col1, #T_24a69_row16_col0, #T_24a69_row16_col1, #T_24a69_row16_col3, #T_24a69_row17_col0, #T_24a69_row17_col1, #T_24a69_row18_col0, #T_24a69_row18_col1, #T_24a69_row19_col0, #T_24a69_row19_col1, #T_24a69_row20_col0, #T_24a69_row20_col1, #T_24a69_row21_col0, #T_24a69_row21_col1, #T_24a69_row21_col3, #T_24a69_row22_col0, #T_24a69_row22_col1, #T_24a69_row23_col0, #T_24a69_row23_col1, #T_24a69_row24_col0, #T_24a69_row24_col1, #T_24a69_row25_col0, #T_24a69_row25_col1, #T_24a69_row26_col0, #T_24a69_row26_col1, #T_24a69_row26_col3, #T_24a69_row27_col0, #T_24a69_row27_col1, #T_24a69_row28_col0, #T_24a69_row28_col1, #T_24a69_row29_col0, #T_24a69_row29_col1, #T_24a69_row30_col0, #T_24a69_row30_col1, #T_24a69_row31_col0, #T_24a69_row31_col1, #T_24a69_row31_col3, #T_24a69_row32_col0, #T_24a69_row32_col1, #T_24a69_row33_col0, #T_24a69_row33_col1, #T_24a69_row34_col0, #T_24a69_row34_col1, #T_24a69_row35_col0, #T_24a69_row35_col1, #T_24a69_row36_col0, #T_24a69_row36_col1, #T_24a69_row36_col3, #T_24a69_row37_col0, #T_24a69_row37_col1, #T_24a69_row38_col0, #T_24a69_row38_col1, #T_24a69_row39_col0, #T_24a69_row39_col1, #T_24a69_row40_col0, #T_24a69_row40_col1, #T_24a69_row41_col0, #T_24a69_row41_col1, #T_24a69_row41_col3, #T_24a69_row41_col4, #T_24a69_row41_col5, #T_24a69_row41_col6, #T_24a69_row41_col8, #T_24a69_row41_col9, #T_24a69_row41_col10, #T_24a69_row41_col11, #T_24a69_row41_col12, #T_24a69_row41_col13, #T_24a69_row41_col14, #T_24a69_row41_col15, #T_24a69_row41_col16, #T_24a69_row41_col17, #T_24a69_row42_col0, #T_24a69_row42_col1, #T_24a69_row43_col0, #T_24a69_row43_col1, #T_24a69_row44_col0, #T_24a69_row44_col1, #T_24a69_row45_col0, #T_24a69_row45_col1, #T_24a69_row46_col0, #T_24a69_row46_col1, #T_24a69_row46_col3, #T_24a69_row47_col0, #T_24a69_row47_col1, #T_24a69_row48_col0, #T_24a69_row48_col1, #T_24a69_row49_col0, #T_24a69_row49_col1, #T_24a69_row50_col0, #T_24a69_row51_col0, #T_24a69_row51_col3, #T_24a69_row52_col0, #T_24a69_row53_col0, #T_24a69_row54_col0, #T_24a69_row55_col0, #T_24a69_row55_col2, #T_24a69_row56_col0, #T_24a69_row56_col2, #T_24a69_row56_col3, #T_24a69_row57_col0, #T_24a69_row57_col2, #T_24a69_row58_col0, #T_24a69_row58_col2, #T_24a69_row59_col0, #T_24a69_row59_col2, #T_24a69_row60_col0, #T_24a69_row61_col0, #T_24a69_row61_col3, #T_24a69_row62_col0, #T_24a69_row63_col0, #T_24a69_row64_col0, #T_24a69_row65_col0, #T_24a69_row66_col0, #T_24a69_row66_col3, #T_24a69_row67_col0, #T_24a69_row68_col0, #T_24a69_row69_col0, #T_24a69_row70_col0, #T_24a69_row71_col0, #T_24a69_row71_col3, #T_24a69_row72_col0, #T_24a69_row73_col0, #T_24a69_row74_col0, #T_24a69_row75_col0, #T_24a69_row76_col0, #T_24a69_row76_col3, #T_24a69_row77_col0, #T_24a69_row78_col0, #T_24a69_row79_col0, #T_24a69_row80_col0, #T_24a69_row81_col0, #T_24a69_row81_col3, #T_24a69_row82_col0, #T_24a69_row83_col ...
#   font-weight: bold;
# }
# #T_24a69_row6_col18, #T_24a69_row41_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# #T_24a69_row15_col16, #T_24a69_row15_col17, #T_24a69_row19_col10, #T_24a69_row19_col11, #T_24a69_row19_col12, #T_24a69_row19_col13, #T_24a69_row19_col15, #T_24a69_row47_col14, #T_24a69_row65_col16, #T_24a69_row65_col17, #T_24a69_row69_col10, #T_24a69_row69_col11, #T_24a69_row69_col12, #T_24a69_row69_col13, #T_24a69_row69_col15, #T_24a69_row97_col14, #T_24a69_row115_col16, #T_24a69_row115_col17, #T_24a69_row119_col10, #T_24a69_row119_col11, #T_24a69_row119_col12, #T_24a69_row119_col13, #T_24a69_row119_col15, #T_24a69_row165_col16, #T_24a69_row165_col17, #T_24a69_row169_col10, #T_24a69_r

# %% [markdown]
# ### Random Forest

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'n_estimators':[10, 50],'criterion':['gini', 'entropy'], 'max_depth':[16]}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_rf = fair_GridsearchCV(base='RF', param_grid=param_grid,
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_rf.fit(X=X, y=y)
    
results_rf = clf_rf.output_table
print(clf_rf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_rf.to_pickle('./{}_results/{}_results_RF'.format(data_name, data_name))
style_table(results_rf)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'criterion': 'gini', 'max_depth': 16, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:18<00:56, 18.94s/it]
# {'criterion': 'gini', 'max_depth': 16, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [00:42<00:42, 21.43s/it]
# {'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [00:58<00:19, 19.24s/it]
# {'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [01:21<00:00, 20.34s/it]
# base_estimator                                                    RF
# param              {'criterion': 'gini', 'max_depth': 16, 'n_esti...
# Bias_Mitigation                                                   RW
# threshold                                                        0.6
# Name: 48, dtype: object
# Time:  1.3592143400000003 min
# <style type="text/css">
# #T_df05e_row0_col0, #T_df05e_row1_col0, #T_df05e_row2_col0, #T_df05e_row3_col0, #T_df05e_row3_col3, #T_df05e_row4_col0, #T_df05e_row5_col0, #T_df05e_row5_col2, #T_df05e_row6_col0, #T_df05e_row6_col2, #T_df05e_row7_col0, #T_df05e_row7_col2, #T_df05e_row8_col0, #T_df05e_row8_col2, #T_df05e_row8_col3, #T_df05e_row9_col0, #T_df05e_row9_col2, #T_df05e_row10_col0, #T_df05e_row11_col0, #T_df05e_row12_col0, #T_df05e_row13_col0, #T_df05e_row13_col3, #T_df05e_row14_col0, #T_df05e_row15_col0, #T_df05e_row16_col0, #T_df05e_row17_col0, #T_df05e_row18_col0, #T_df05e_row18_col3, #T_df05e_row19_col0, #T_df05e_row20_col0, #T_df05e_row21_col0, #T_df05e_row22_col0, #T_df05e_row23_col0, #T_df05e_row23_col3, #T_df05e_row24_col0, #T_df05e_row25_col0, #T_df05e_row26_col0, #T_df05e_row27_col0, #T_df05e_row28_col0, #T_df05e_row28_col3, #T_df05e_row29_col0, #T_df05e_row30_col0, #T_df05e_row31_col0, #T_df05e_row32_col0, #T_df05e_row33_col0, #T_df05e_row33_col3, #T_df05e_row34_col0, #T_df05e_row35_col0, #T_df05e_row36_col0, #T_df05e_row37_col0, #T_df05e_row38_col0, #T_df05e_row38_col3, #T_df05e_row39_col0, #T_df05e_row40_col0, #T_df05e_row40_col1, #T_df05e_row41_col0, #T_df05e_row41_col1, #T_df05e_row42_col0, #T_df05e_row42_col1, #T_df05e_row43_col0, #T_df05e_row43_col1, #T_df05e_row43_col3, #T_df05e_row44_col0, #T_df05e_row44_col1, #T_df05e_row45_col0, #T_df05e_row45_col1, #T_df05e_row45_col2, #T_df05e_row45_col7, #T_df05e_row46_col0, #T_df05e_row46_col1, #T_df05e_row46_col2, #T_df05e_row46_col7, #T_df05e_row47_col0, #T_df05e_row47_col1, #T_df05e_row47_col2, #T_df05e_row47_col7, #T_df05e_row48_col0, #T_df05e_row48_col1, #T_df05e_row48_col2, #T_df05e_row48_col3, #T_df05e_row48_col4, #T_df05e_row48_col5, #T_df05e_row48_col6, #T_df05e_row48_col7, #T_df05e_row48_col8, #T_df05e_row48_col9, #T_df05e_row48_col10, #T_df05e_row48_col11, #T_df05e_row48_col12, #T_df05e_row48_col13, #T_df05e_row48_col14, #T_df05e_row48_col15, #T_df05e_row48_col16, #T_df05e_row48_col17, #T_df05e_row49_col0, #T_df05e_row49_col1, #T_df05e_row49_col2, #T_df05e_row49_col7, #T_df05e_row50_col0, #T_df05e_row50_col1, #T_df05e_row51_col0, #T_df05e_row51_col1, #T_df05e_row52_col0, #T_df05e_row52_col1, #T_df05e_row53_col0, #T_df05e_row53_col1, #T_df05e_row53_col3, #T_df05e_row54_col0, #T_df05e_row54_col1, #T_df05e_row55_col0, #T_df05e_row55_col1, #T_df05e_row56_col0, #T_df05e_row56_col1, #T_df05e_row57_col0, #T_df05e_row57_col1, #T_df05e_row58_col0, #T_df05e_row58_col1, #T_df05e_row58_col3, #T_df05e_row59_col0, #T_df05e_row59_col1, #T_df05e_row60_col0, #T_df05e_row60_col1, #T_df05e_row61_col0, #T_df05e_row61_col1, #T_df05e_row62_col0, #T_df05e_row62_col1, #T_df05e_row63_col0, #T_df05e_row63_col1, #T_df05e_row63_col3, #T_df05e_row64_col0, #T_df05e_row64_col1, #T_df05e_row65_col0, #T_df05e_row65_col1, #T_df05e_row66_col0, #T_df05e_row66_col1, #T_df05e_row67_col0, #T_df05e_row67_col1, #T_df05e_row68_col0, #T_df05e_row68_col1, #T_df05e_row68_col3, #T_df05e_row69_col0, #T_df05e_row69_col1, #T_df05e_row70_col0, #T_df05e_row70_col1, #T_df05e_row71_col0, #T_df05e_row71_col1, #T_df05e_row72_col0, #T_df05e_row72_col1, #T_df05e_row73_col0, #T_df05e_row73_col1, #T_df05e_row73_col3, #T_df05e_row73_col4, #T_df05e_row73_col5, #T_df05e_row73_col6, #T_df05e_row73_col8, #T_df05e_row73_col9, #T_df05e_row73_col10, #T_df05e_row73_col11, #T_df05e_row73_col12, #T_df05e_row73_col13, #T_df05e_row73_col14, #T_df05e_row73_col15, #T_df05e_row73_col16, #T_df05e_row73_col17, #T_df05e_row74_col0, #T_df05e_row74_col1, #T_df05e_row75_col0, #T_df05e_row75_col1, #T_df05e_row76_col0, #T_df05e_row76_col1, #T_df05e_row77_col0, #T_df05e_row77_col1, #T_df05e_row78_col0, #T_df05e_row78_col1, #T_df05e_row78_col3, #T_df05e_row79_col0, #T_df05e_row79_col1, #T_df05e_row80_col0, #T_df05e_row81_col0, #T_df05e_row82_col0, #T_df05e_row83_col0, #T_df05e_row83_col3, #T_df05e_row84_col0, #T_df05e_row85_col0, #T_df05e_row85_col2, #T_df05e_row86_col0, #T_df05e_row86_col2, #T_df05e_row87_col0, #T_df05e_row87_col2, #T_df05e_row88_col0, #T_df05e_ro ...
#   font-weight: bold;
# }
# #T_df05e_row25_col14, #T_df05e_row50_col16, #T_df05e_row50_col17, #T_df05e_row54_col10, #T_df05e_row54_col11, #T_df05e_row54_col12, #T_df05e_row54_col13, #T_df05e_row54_col15, #T_df05e_row134_col10, #T_df05e_row134_col11, #T_df05e_row134_col12, #T_df05e_row134_col13, #T_df05e_row134_col15 {
#   background: yellow;
# }
# #T_df05e_row45_col6, #T_df05e_row70_col6, #T_df05e_row123_col4, #T_df05e_row125_col5, #T_df05e_row125_col7, #T_df05e_row126_col7, #T_df05e_row127_col7, #T_df05e_row127_col8, #T_df05e_row127_col9, #T_df05e_row128_col7, #T_df05e_row129_col7, #T_df05e_row143_col4, #T_df05e_row150_col5 {
#   background-color: lightgreen;
# }
# #T_df05e_row48_col18, #T_df05e_row73_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_df05e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df05e_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_df05e_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_df05e_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_df05e_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_df05e_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_df05e_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_df05e_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_df05e_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_df05e_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_df05e_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_df05e_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_df05e_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_df05e_level0_col12" class="col_heading level0

# %% [markdown]
# ### Gradient Boosting

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'n_estimators':[10, 50],'criterion':['friedman_mse'],'max_depth':[8, 32]}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_gb = fair_GridsearchCV(base='GB', param_grid=param_grid,
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_gb.fit(X=X, y=y)
    
results_gb = clf_gb.output_table
print(clf_gb._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_gb.to_pickle('./{}_results/{}_results_GB'.format(data_name, data_name))
style_table(results_gb)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'criterion': 'friedman_mse', 'max_depth': 8, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:18<00:55, 18.59s/it]
# {'criterion': 'friedman_mse', 'max_depth': 8, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [01:34<01:45, 52.55s/it]
# {'criterion': 'friedman_mse', 'max_depth': 32, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [02:17<00:48, 48.13s/it]
# {'criterion': 'friedman_mse', 'max_depth': 32, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [04:21<00:00, 65.44s/it]
# base_estimator                                                    GB
# param              {'criterion': 'friedman_mse', 'max_depth': 8, ...
# Bias_Mitigation                                                 None
# threshold                                                        0.5
# Name: 42, dtype: object
# Time:  4.366142474999999 min
# <style type="text/css">
# #T_0a5ec_row0_col0, #T_0a5ec_row0_col2, #T_0a5ec_row1_col0, #T_0a5ec_row1_col2, #T_0a5ec_row2_col0, #T_0a5ec_row2_col2, #T_0a5ec_row2_col3, #T_0a5ec_row3_col0, #T_0a5ec_row3_col2, #T_0a5ec_row4_col0, #T_0a5ec_row4_col2, #T_0a5ec_row5_col0, #T_0a5ec_row6_col0, #T_0a5ec_row7_col0, #T_0a5ec_row7_col3, #T_0a5ec_row8_col0, #T_0a5ec_row9_col0, #T_0a5ec_row10_col0, #T_0a5ec_row11_col0, #T_0a5ec_row12_col0, #T_0a5ec_row12_col3, #T_0a5ec_row13_col0, #T_0a5ec_row14_col0, #T_0a5ec_row15_col0, #T_0a5ec_row16_col0, #T_0a5ec_row17_col0, #T_0a5ec_row17_col3, #T_0a5ec_row18_col0, #T_0a5ec_row19_col0, #T_0a5ec_row20_col0, #T_0a5ec_row21_col0, #T_0a5ec_row22_col0, #T_0a5ec_row22_col3, #T_0a5ec_row23_col0, #T_0a5ec_row24_col0, #T_0a5ec_row25_col0, #T_0a5ec_row26_col0, #T_0a5ec_row27_col0, #T_0a5ec_row27_col3, #T_0a5ec_row28_col0, #T_0a5ec_row29_col0, #T_0a5ec_row30_col0, #T_0a5ec_row31_col0, #T_0a5ec_row32_col0, #T_0a5ec_row32_col3, #T_0a5ec_row33_col0, #T_0a5ec_row34_col0, #T_0a5ec_row35_col0, #T_0a5ec_row36_col0, #T_0a5ec_row37_col0, #T_0a5ec_row37_col3, #T_0a5ec_row38_col0, #T_0a5ec_row39_col0, #T_0a5ec_row40_col0, #T_0a5ec_row40_col1, #T_0a5ec_row40_col2, #T_0a5ec_row40_col7, #T_0a5ec_row41_col0, #T_0a5ec_row41_col1, #T_0a5ec_row41_col2, #T_0a5ec_row41_col7, #T_0a5ec_row42_col0, #T_0a5ec_row42_col1, #T_0a5ec_row42_col2, #T_0a5ec_row42_col3, #T_0a5ec_row42_col4, #T_0a5ec_row42_col5, #T_0a5ec_row42_col6, #T_0a5ec_row42_col7, #T_0a5ec_row42_col8, #T_0a5ec_row42_col9, #T_0a5ec_row42_col10, #T_0a5ec_row42_col11, #T_0a5ec_row42_col12, #T_0a5ec_row42_col13, #T_0a5ec_row42_col14, #T_0a5ec_row42_col15, #T_0a5ec_row42_col16, #T_0a5ec_row42_col17, #T_0a5ec_row43_col0, #T_0a5ec_row43_col1, #T_0a5ec_row43_col2, #T_0a5ec_row43_col7, #T_0a5ec_row44_col0, #T_0a5ec_row44_col1, #T_0a5ec_row44_col2, #T_0a5ec_row44_col7, #T_0a5ec_row45_col0, #T_0a5ec_row45_col1, #T_0a5ec_row46_col0, #T_0a5ec_row46_col1, #T_0a5ec_row47_col0, #T_0a5ec_row47_col1, #T_0a5ec_row47_col3, #T_0a5ec_row48_col0, #T_0a5ec_row48_col1, #T_0a5ec_row49_col0, #T_0a5ec_row49_col1, #T_0a5ec_row50_col0, #T_0a5ec_row50_col1, #T_0a5ec_row51_col0, #T_0a5ec_row51_col1, #T_0a5ec_row52_col0, #T_0a5ec_row52_col1, #T_0a5ec_row52_col3, #T_0a5ec_row53_col0, #T_0a5ec_row53_col1, #T_0a5ec_row54_col0, #T_0a5ec_row54_col1, #T_0a5ec_row55_col0, #T_0a5ec_row55_col1, #T_0a5ec_row56_col0, #T_0a5ec_row56_col1, #T_0a5ec_row57_col0, #T_0a5ec_row57_col1, #T_0a5ec_row57_col3, #T_0a5ec_row58_col0, #T_0a5ec_row58_col1, #T_0a5ec_row59_col0, #T_0a5ec_row59_col1, #T_0a5ec_row60_col0, #T_0a5ec_row60_col1, #T_0a5ec_row61_col0, #T_0a5ec_row61_col1, #T_0a5ec_row62_col0, #T_0a5ec_row62_col1, #T_0a5ec_row62_col3, #T_0a5ec_row63_col0, #T_0a5ec_row63_col1, #T_0a5ec_row64_col0, #T_0a5ec_row64_col1, #T_0a5ec_row65_col0, #T_0a5ec_row65_col1, #T_0a5ec_row66_col0, #T_0a5ec_row66_col1, #T_0a5ec_row67_col0, #T_0a5ec_row67_col1, #T_0a5ec_row67_col3, #T_0a5ec_row68_col0, #T_0a5ec_row68_col1, #T_0a5ec_row69_col0, #T_0a5ec_row69_col1, #T_0a5ec_row70_col0, #T_0a5ec_row70_col1, #T_0a5ec_row71_col0, #T_0a5ec_row71_col1, #T_0a5ec_row72_col0, #T_0a5ec_row72_col1, #T_0a5ec_row72_col3, #T_0a5ec_row73_col0, #T_0a5ec_row73_col1, #T_0a5ec_row74_col0, #T_0a5ec_row74_col1, #T_0a5ec_row75_col0, #T_0a5ec_row75_col1, #T_0a5ec_row76_col0, #T_0a5ec_row76_col1, #T_0a5ec_row77_col0, #T_0a5ec_row77_col1, #T_0a5ec_row77_col3, #T_0a5ec_row78_col0, #T_0a5ec_row78_col1, #T_0a5ec_row79_col0, #T_0a5ec_row79_col1, #T_0a5ec_row80_col0, #T_0a5ec_row80_col2, #T_0a5ec_row81_col0, #T_0a5ec_row81_col2, #T_0a5ec_row82_col0, #T_0a5ec_row82_col2, #T_0a5ec_row82_col3, #T_0a5ec_row83_col0, #T_0a5ec_row83_col2, #T_0a5ec_row84_col0, #T_0a5ec_row84_col2, #T_0a5ec_row85_col0, #T_0a5ec_row86_col0, #T_0a5ec_row87_col0, #T_0a5ec_row87_col3, #T_0a5ec_row88_col0, #T_0a5ec_row89_col0, #T_0a5ec_row90_col0, #T_0a5ec_row91_col0, #T_0a5ec_row92_col0, #T_0a5ec_row92_col3, #T_0a5ec_row93_col0, #T_0a5ec_row94_col0, #T_0a5ec_row95_col0, #T_0a5ec_row96_col0, #T_0a5ec_row97_col0, #T_0a5ec_row97_col3 ...
#   font-weight: bold;
# }
# #T_0a5ec_row3_col14, #T_0a5ec_row10_col16, #T_0a5ec_row10_col17, #T_0a5ec_row14_col15, #T_0a5ec_row23_col14, #T_0a5ec_row47_col11, #T_0a5ec_row54_col13, #T_0a5ec_row91_col10, #T_0a5ec_row134_col12 {
#   background: yellow;
# }
# #T_0a5ec_row40_col5, #T_0a5ec_row40_col6, #T_0a5ec_row44_col4, #T_0a5ec_row46_col8, #T_0a5ec_row46_col9, #T_0a5ec_row60_col5, #T_0a5ec_row60_col6, #T_0a5ec_row62_col7, #T_0a5ec_row64_col4, #T_0a5ec_row71_col8, #T_0a5ec_row71_col9 {
#   background-color: lightgreen;
# }
# #T_0a5ec_row42_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_0a5ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a5ec_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_0a5ec_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_0a5ec_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_0a5ec_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_0a5ec_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_0a5ec_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_0a5ec_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_0a5ec_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_0a5ec_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_0a5ec_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_0a5ec_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_0a5ec_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_0a5ec_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_0a5ec_level0_col13" class="col_heading level0 col13" >avg_ford_score</th>
#       <th id="T_0a5ec_level0_col14" class="col_heading level0 col14" >avg_ppvd_score</th>
#       <th id="T_0a5ec_level0_col15" class="col_heading level0 col15" >avg_(1-consistency_score)</th>
#       <th id="T_0a5ec_level0_col16" class="col_heading level0 col16" >avg_gei_score</th>
#       <th id="T_0a5ec_level0_col17" class="col_headi

# %% [markdown]
# ### Support Vector Machine

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'kernel':['rbf','linear','poly','sigmoid'],'gamma':['scale']},
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_svm = fair_GridsearchCV(base='SVM', param_grid=param_grid,
                            prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                            cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_svm.fit(X=X, y=y)
    
results_svm = clf_svm.output_table
print(clf_svm._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_svm.to_pickle('./{}_results/{}_results_SVM'.format(data_name, data_name))
style_table(results_svm)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'gamma': 'scale', 'kernel': 'rbf'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:30<01:32, 30.76s/it]
# {'gamma': 'scale', 'kernel': 'linear'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [00:53<00:52, 26.09s/it]
# {'gamma': 'scale', 'kernel': 'poly'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [01:16<00:24, 24.54s/it]
# {'gamma': 'scale', 'kernel': 'sigmoid'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [01:42<00:00, 25.72s/it]
# base_estimator                                        SVM
# param              {'gamma': 'scale', 'kernel': 'linear'}
# Bias_Mitigation                                      None
# threshold                                             0.3
# Name: 40, dtype: object
# Time:  1.7186631583333338 min
# <style type="text/css">
# #T_b7981_row0_col0, #T_b7981_row0_col2, #T_b7981_row0_col3, #T_b7981_row1_col0, #T_b7981_row1_col2, #T_b7981_row2_col0, #T_b7981_row2_col2, #T_b7981_row3_col0, #T_b7981_row3_col2, #T_b7981_row4_col0, #T_b7981_row4_col2, #T_b7981_row5_col0, #T_b7981_row5_col3, #T_b7981_row6_col0, #T_b7981_row7_col0, #T_b7981_row8_col0, #T_b7981_row9_col0, #T_b7981_row10_col0, #T_b7981_row10_col3, #T_b7981_row11_col0, #T_b7981_row12_col0, #T_b7981_row13_col0, #T_b7981_row14_col0, #T_b7981_row15_col0, #T_b7981_row15_col3, #T_b7981_row16_col0, #T_b7981_row17_col0, #T_b7981_row18_col0, #T_b7981_row19_col0, #T_b7981_row20_col0, #T_b7981_row20_col3, #T_b7981_row21_col0, #T_b7981_row22_col0, #T_b7981_row23_col0, #T_b7981_row24_col0, #T_b7981_row25_col0, #T_b7981_row25_col3, #T_b7981_row26_col0, #T_b7981_row27_col0, #T_b7981_row28_col0, #T_b7981_row29_col0, #T_b7981_row30_col0, #T_b7981_row30_col3, #T_b7981_row31_col0, #T_b7981_row32_col0, #T_b7981_row33_col0, #T_b7981_row34_col0, #T_b7981_row35_col0, #T_b7981_row35_col3, #T_b7981_row36_col0, #T_b7981_row37_col0, #T_b7981_row38_col0, #T_b7981_row39_col0, #T_b7981_row40_col0, #T_b7981_row40_col1, #T_b7981_row40_col2, #T_b7981_row40_col3, #T_b7981_row40_col4, #T_b7981_row40_col5, #T_b7981_row40_col6, #T_b7981_row40_col7, #T_b7981_row40_col8, #T_b7981_row40_col9, #T_b7981_row40_col10, #T_b7981_row40_col11, #T_b7981_row40_col12, #T_b7981_row40_col13, #T_b7981_row40_col14, #T_b7981_row40_col15, #T_b7981_row40_col16, #T_b7981_row40_col17, #T_b7981_row41_col0, #T_b7981_row41_col1, #T_b7981_row41_col2, #T_b7981_row41_col7, #T_b7981_row42_col0, #T_b7981_row42_col1, #T_b7981_row42_col2, #T_b7981_row42_col7, #T_b7981_row43_col0, #T_b7981_row43_col1, #T_b7981_row43_col2, #T_b7981_row43_col7, #T_b7981_row44_col0, #T_b7981_row44_col1, #T_b7981_row44_col2, #T_b7981_row44_col7, #T_b7981_row45_col0, #T_b7981_row45_col1, #T_b7981_row45_col3, #T_b7981_row46_col0, #T_b7981_row46_col1, #T_b7981_row47_col0, #T_b7981_row47_col1, #T_b7981_row48_col0, #T_b7981_row48_col1, #T_b7981_row49_col0, #T_b7981_row49_col1, #T_b7981_row50_col0, #T_b7981_row50_col1, #T_b7981_row50_col3, #T_b7981_row51_col0, #T_b7981_row51_col1, #T_b7981_row52_col0, #T_b7981_row52_col1, #T_b7981_row53_col0, #T_b7981_row53_col1, #T_b7981_row54_col0, #T_b7981_row54_col1, #T_b7981_row55_col0, #T_b7981_row55_col1, #T_b7981_row55_col3, #T_b7981_row56_col0, #T_b7981_row56_col1, #T_b7981_row57_col0, #T_b7981_row57_col1, #T_b7981_row58_col0, #T_b7981_row58_col1, #T_b7981_row59_col0, #T_b7981_row59_col1, #T_b7981_row60_col0, #T_b7981_row60_col1, #T_b7981_row60_col3, #T_b7981_row60_col4, #T_b7981_row60_col5, #T_b7981_row60_col6, #T_b7981_row60_col8, #T_b7981_row60_col9, #T_b7981_row60_col10, #T_b7981_row60_col11, #T_b7981_row60_col12, #T_b7981_row60_col13, #T_b7981_row60_col14, #T_b7981_row60_col15, #T_b7981_row60_col16, #T_b7981_row60_col17, #T_b7981_row61_col0, #T_b7981_row61_col1, #T_b7981_row62_col0, #T_b7981_row62_col1, #T_b7981_row63_col0, #T_b7981_row63_col1, #T_b7981_row64_col0, #T_b7981_row64_col1, #T_b7981_row65_col0, #T_b7981_row65_col1, #T_b7981_row65_col3, #T_b7981_row66_col0, #T_b7981_row66_col1, #T_b7981_row67_col0, #T_b7981_row67_col1, #T_b7981_row68_col0, #T_b7981_row68_col1, #T_b7981_row69_col0, #T_b7981_row69_col1, #T_b7981_row70_col0, #T_b7981_row70_col1, #T_b7981_row70_col3, #T_b7981_row71_col0, #T_b7981_row71_col1, #T_b7981_row72_col0, #T_b7981_row72_col1, #T_b7981_row73_col0, #T_b7981_row73_col1, #T_b7981_row74_col0, #T_b7981_row74_col1, #T_b7981_row75_col0, #T_b7981_row75_col1, #T_b7981_row75_col3, #T_b7981_row76_col0, #T_b7981_row76_col1, #T_b7981_row77_col0, #T_b7981_row77_col1, #T_b7981_row78_col0, #T_b7981_row78_col1, #T_b7981_row79_col0, #T_b7981_row79_col1, #T_b7981_row80_col0, #T_b7981_row80_col2, #T_b7981_row80_col3, #T_b7981_row81_col0, #T_b7981_row81_col2, #T_b7981_row82_col0, #T_b7981_row82_col2, #T_b7981_row83_col0, #T_b7981_row83_col2, #T_b7981_row84_col0, #T_b7981_row84_col2, #T_b7981_row85_col0, #T_b7981_row85_col3, #T_b7981_ro ...
#   font-weight: bold;
# }
# #T_b7981_row10_col10, #T_b7981_row10_col11, #T_b7981_row10_col12, #T_b7981_row10_col14, #T_b7981_row10_col15, #T_b7981_row10_col16, #T_b7981_row10_col17, #T_b7981_row11_col10, #T_b7981_row11_col11, #T_b7981_row11_col12, #T_b7981_row11_col15, #T_b7981_row12_col10, #T_b7981_row12_col11, #T_b7981_row12_col12, #T_b7981_row12_col15, #T_b7981_row13_col10, #T_b7981_row13_col11, #T_b7981_row13_col12, #T_b7981_row13_col13, #T_b7981_row13_col15, #T_b7981_row14_col10, #T_b7981_row14_col11, #T_b7981_row14_col12, #T_b7981_row14_col13, #T_b7981_row14_col15, #T_b7981_row109_col13, #T_b7981_row119_col13, #T_b7981_row133_col10, #T_b7981_row133_col11, #T_b7981_row133_col12, #T_b7981_row133_col13, #T_b7981_row133_col15, #T_b7981_row134_col10, #T_b7981_row134_col11, #T_b7981_row134_col12, #T_b7981_row134_col13, #T_b7981_row134_col15 {
#   background: yellow;
# }
# #T_b7981_row40_col18, #T_b7981_row60_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# #T_b7981_row41_col4, #T_b7981_row45_col5, #T_b7981_row45_col6, #T_b7981_row45_col7, #T_b7981_row45_col8, #T_b7981_row45_col9, #T_b7981_row46_col7, #T_b7981_row47_col7, #T_b7981_row48_col7, #T_b7981_row49_col7, #T_b7981_row61_col4, #T_b7981_row70_col5, #T_b7981_row70_col6, #T_b7981_row70_col8, #T_b7981_row70_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b7981">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7981_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_b7981_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_b7981_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_b7981_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_b7981_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_b7981_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_b7981_leve

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
# model for Reweighing
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'var_smoothing': np.logspace(0,-9, num=4)}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_nb = fair_GridsearchCV(base='NB', param_grid=param_grid, 
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_nb.fit(X=X, y=y)
    
results_nb = clf_nb.output_table
# print(clf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_nb.to_pickle('./{}_results/{}_results_NB'.format(data_name, data_name))
style_table(results_nb)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'var_smoothing': 1.0}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:15<00:46, 15.37s/it]
# {'var_smoothing': 0.001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [00:31<00:31, 15.88s/it]
# {'var_smoothing': 1e-06}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [00:47<00:15, 15.79s/it]
# {'var_smoothing': 1e-09}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [01:02<00:00, 15.72s/it]
# Time:  1.0512449766666672 min
# <style type="text/css">
# #T_981b5_row0_col0, #T_981b5_row0_col1, #T_981b5_row0_col3, #T_981b5_row1_col0, #T_981b5_row1_col1, #T_981b5_row2_col0, #T_981b5_row2_col1, #T_981b5_row3_col0, #T_981b5_row3_col1, #T_981b5_row4_col0, #T_981b5_row4_col1, #T_981b5_row5_col0, #T_981b5_row5_col1, #T_981b5_row5_col3, #T_981b5_row6_col0, #T_981b5_row6_col1, #T_981b5_row7_col0, #T_981b5_row7_col1, #T_981b5_row8_col0, #T_981b5_row8_col1, #T_981b5_row9_col0, #T_981b5_row9_col1, #T_981b5_row10_col0, #T_981b5_row10_col1, #T_981b5_row10_col3, #T_981b5_row11_col0, #T_981b5_row11_col1, #T_981b5_row12_col0, #T_981b5_row12_col1, #T_981b5_row13_col0, #T_981b5_row13_col1, #T_981b5_row14_col0, #T_981b5_row14_col1, #T_981b5_row15_col0, #T_981b5_row15_col1, #T_981b5_row15_col3, #T_981b5_row16_col0, #T_981b5_row16_col1, #T_981b5_row17_col0, #T_981b5_row17_col1, #T_981b5_row18_col0, #T_981b5_row18_col1, #T_981b5_row19_col0, #T_981b5_row19_col1, #T_981b5_row20_col0, #T_981b5_row20_col1, #T_981b5_row20_col3, #T_981b5_row21_col0, #T_981b5_row21_col1, #T_981b5_row22_col0, #T_981b5_row22_col1, #T_981b5_row23_col0, #T_981b5_row23_col1, #T_981b5_row24_col0, #T_981b5_row24_col1, #T_981b5_row25_col0, #T_981b5_row25_col1, #T_981b5_row25_col3, #T_981b5_row25_col4, #T_981b5_row26_col0, #T_981b5_row26_col1, #T_981b5_row27_col0, #T_981b5_row27_col1, #T_981b5_row28_col0, #T_981b5_row28_col1, #T_981b5_row29_col0, #T_981b5_row29_col1, #T_981b5_row30_col0, #T_981b5_row30_col1, #T_981b5_row30_col3, #T_981b5_row31_col0, #T_981b5_row31_col1, #T_981b5_row32_col0, #T_981b5_row32_col1, #T_981b5_row33_col0, #T_981b5_row33_col1, #T_981b5_row34_col0, #T_981b5_row34_col1, #T_981b5_row35_col0, #T_981b5_row35_col1, #T_981b5_row35_col2, #T_981b5_row35_col3, #T_981b5_row35_col4, #T_981b5_row35_col5, #T_981b5_row35_col6, #T_981b5_row35_col7, #T_981b5_row35_col8, #T_981b5_row35_col9, #T_981b5_row35_col10, #T_981b5_row35_col11, #T_981b5_row35_col12, #T_981b5_row35_col13, #T_981b5_row35_col14, #T_981b5_row35_col15, #T_981b5_row36_col0, #T_981b5_row36_col1, #T_981b5_row36_col2, #T_981b5_row36_col7, #T_981b5_row37_col0, #T_981b5_row37_col1, #T_981b5_row37_col2, #T_981b5_row37_col7, #T_981b5_row38_col0, #T_981b5_row38_col1, #T_981b5_row38_col2, #T_981b5_row38_col7, #T_981b5_row39_col0, #T_981b5_row39_col1, #T_981b5_row39_col2, #T_981b5_row39_col7, #T_981b5_row40_col0, #T_981b5_row40_col3, #T_981b5_row41_col0, #T_981b5_row42_col0, #T_981b5_row43_col0, #T_981b5_row44_col0, #T_981b5_row45_col0, #T_981b5_row45_col3, #T_981b5_row46_col0, #T_981b5_row47_col0, #T_981b5_row48_col0, #T_981b5_row49_col0, #T_981b5_row50_col0, #T_981b5_row50_col3, #T_981b5_row51_col0, #T_981b5_row52_col0, #T_981b5_row53_col0, #T_981b5_row54_col0, #T_981b5_row55_col0, #T_981b5_row55_col3, #T_981b5_row56_col0, #T_981b5_row57_col0, #T_981b5_row58_col0, #T_981b5_row59_col0, #T_981b5_row60_col0, #T_981b5_row60_col3, #T_981b5_row61_col0, #T_981b5_row62_col0, #T_981b5_row63_col0, #T_981b5_row64_col0, #T_981b5_row65_col0, #T_981b5_row65_col3, #T_981b5_row66_col0, #T_981b5_row67_col0, #T_981b5_row68_col0, #T_981b5_row69_col0, #T_981b5_row70_col0, #T_981b5_row70_col3, #T_981b5_row71_col0, #T_981b5_row72_col0, #T_981b5_row73_col0, #T_981b5_row74_col0, #T_981b5_row75_col0, #T_981b5_row75_col2, #T_981b5_row75_col3, #T_981b5_row76_col0, #T_981b5_row76_col2, #T_981b5_row77_col0, #T_981b5_row77_col2, #T_981b5_row78_col0, #T_981b5_row78_col2, #T_981b5_row79_col0, #T_981b5_row79_col2, #T_981b5_row80_col0, #T_981b5_row80_col3, #T_981b5_row81_col0, #T_981b5_row82_col0, #T_981b5_row83_col0, #T_981b5_row84_col0, #T_981b5_row85_col0, #T_981b5_row85_col3, #T_981b5_row86_col0, #T_981b5_row87_col0, #T_981b5_row88_col0, #T_981b5_row89_col0, #T_981b5_row90_col0, #T_981b5_row90_col3, #T_981b5_row91_col0, #T_981b5_row92_col0, #T_981b5_row93_col0, #T_981b5_row94_col0, #T_981b5_row95_col0, #T_981b5_row95_col3, #T_981b5_row96_col0, #T_981b5_row97_col0, #T_981b5_row98_col0, #T_981b5_row99_col0, #T_981b5_row100_col0, #T_981b5_row100_col3, #T_981b5_row101_col0, #T_981b5_row102_col0, # ...
#   font-weight: bold;
# }
# #T_981b5_row1_col14, #T_981b5_row14_col10, #T_981b5_row14_col11, #T_981b5_row14_col12, #T_981b5_row14_col15, #T_981b5_row17_col13, #T_981b5_row21_col14 {
#   background: yellow;
# }
# #T_981b5_row5_col6, #T_981b5_row5_col7, #T_981b5_row6_col7, #T_981b5_row7_col7, #T_981b5_row8_col4, #T_981b5_row8_col7, #T_981b5_row9_col7, #T_981b5_row30_col6, #T_981b5_row33_col4, #T_981b5_row45_col5, #T_981b5_row48_col8, #T_981b5_row48_col9, #T_981b5_row70_col5, #T_981b5_row73_col8, #T_981b5_row73_col9, #T_981b5_row85_col5, #T_981b5_row88_col8, #T_981b5_row88_col9, #T_981b5_row110_col5, #T_981b5_row113_col8, #T_981b5_row113_col9, #T_981b5_row125_col5, #T_981b5_row128_col8, #T_981b5_row128_col9, #T_981b5_row150_col5, #T_981b5_row153_col8, #T_981b5_row153_col9 {
#   background-color: lightgreen;
# }
# #T_981b5_row35_col16, #T_981b5_row35_col17 {
#   background: yellow;
#   font-weight: bold;
# }
# #T_981b5_row35_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_981b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_981b5_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_981b5_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_981b5_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_981b5_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_981b5_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_981b5_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_981b5_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_981b5_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_981b5_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_981b5_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_981b5_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_981b5_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_981b5_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_981b5_level0_col13" class="col_heading level0

# %% [markdown]
# ### TabTransformer

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'epochs':[20, 30],'learing_rate':[1e-04, 1e-05]},
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','ROC','CEO','RW+ROC','RW+CEO']}

clf_tab = fair_GridsearchCV(base='TabTrans',param_grid=param_grid, 
                            prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                            cv=cv, n_jobs=n_jobs)

clf_tab.fit(X=X, y=y)
results_tab = clf_tab.output_table
# print(clf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_tab.to_pickle('./{}_results/{}_results_TabTrans'.format(data_name, data_name))

style_table(results_tab)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'epochs': 20, 'learing_rate': 0.0001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [02:07<06:21, 127.28s/it]
# {'epochs': 20, 'learing_rate': 1e-05}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [04:13<04:12, 126.38s/it]
# {'epochs': 30, 'learing_rate': 0.0001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [06:19<02:06, 126.59s/it]
# {'epochs': 30, 'learing_rate': 1e-05}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [08:59<00:00, 135.00s/it]
# Time:  9.006122326666667 min
# <style type="text/css">
# #T_3dd9c_row0_col0, #T_3dd9c_row1_col0, #T_3dd9c_row2_col0, #T_3dd9c_row3_col0, #T_3dd9c_row3_col3, #T_3dd9c_row4_col0, #T_3dd9c_row5_col0, #T_3dd9c_row5_col2, #T_3dd9c_row6_col0, #T_3dd9c_row6_col2, #T_3dd9c_row7_col0, #T_3dd9c_row7_col2, #T_3dd9c_row8_col0, #T_3dd9c_row8_col2, #T_3dd9c_row8_col3, #T_3dd9c_row9_col0, #T_3dd9c_row9_col2, #T_3dd9c_row10_col0, #T_3dd9c_row11_col0, #T_3dd9c_row12_col0, #T_3dd9c_row13_col0, #T_3dd9c_row13_col3, #T_3dd9c_row14_col0, #T_3dd9c_row15_col0, #T_3dd9c_row16_col0, #T_3dd9c_row17_col0, #T_3dd9c_row18_col0, #T_3dd9c_row18_col3, #T_3dd9c_row19_col0, #T_3dd9c_row20_col0, #T_3dd9c_row21_col0, #T_3dd9c_row22_col0, #T_3dd9c_row23_col0, #T_3dd9c_row23_col3, #T_3dd9c_row24_col0, #T_3dd9c_row25_col0, #T_3dd9c_row26_col0, #T_3dd9c_row27_col0, #T_3dd9c_row28_col0, #T_3dd9c_row28_col3, #T_3dd9c_row29_col0, #T_3dd9c_row30_col0, #T_3dd9c_row31_col0, #T_3dd9c_row32_col0, #T_3dd9c_row33_col0, #T_3dd9c_row33_col3, #T_3dd9c_row34_col0, #T_3dd9c_row35_col0, #T_3dd9c_row35_col2, #T_3dd9c_row36_col0, #T_3dd9c_row36_col2, #T_3dd9c_row37_col0, #T_3dd9c_row37_col2, #T_3dd9c_row38_col0, #T_3dd9c_row38_col2, #T_3dd9c_row38_col3, #T_3dd9c_row39_col0, #T_3dd9c_row39_col2, #T_3dd9c_row40_col0, #T_3dd9c_row41_col0, #T_3dd9c_row42_col0, #T_3dd9c_row43_col0, #T_3dd9c_row43_col3, #T_3dd9c_row44_col0, #T_3dd9c_row45_col0, #T_3dd9c_row46_col0, #T_3dd9c_row47_col0, #T_3dd9c_row48_col0, #T_3dd9c_row48_col3, #T_3dd9c_row49_col0, #T_3dd9c_row50_col0, #T_3dd9c_row51_col0, #T_3dd9c_row52_col0, #T_3dd9c_row53_col0, #T_3dd9c_row53_col3, #T_3dd9c_row54_col0, #T_3dd9c_row55_col0, #T_3dd9c_row56_col0, #T_3dd9c_row57_col0, #T_3dd9c_row58_col0, #T_3dd9c_row58_col3, #T_3dd9c_row59_col0, #T_3dd9c_row60_col0, #T_3dd9c_row61_col0, #T_3dd9c_row62_col0, #T_3dd9c_row63_col0, #T_3dd9c_row63_col3, #T_3dd9c_row64_col0, #T_3dd9c_row65_col0, #T_3dd9c_row65_col2, #T_3dd9c_row66_col0, #T_3dd9c_row66_col2, #T_3dd9c_row67_col0, #T_3dd9c_row67_col2, #T_3dd9c_row68_col0, #T_3dd9c_row68_col2, #T_3dd9c_row68_col3, #T_3dd9c_row69_col0, #T_3dd9c_row69_col2, #T_3dd9c_row70_col0, #T_3dd9c_row71_col0, #T_3dd9c_row72_col0, #T_3dd9c_row73_col0, #T_3dd9c_row73_col3, #T_3dd9c_row74_col0, #T_3dd9c_row75_col0, #T_3dd9c_row76_col0, #T_3dd9c_row77_col0, #T_3dd9c_row78_col0, #T_3dd9c_row78_col3, #T_3dd9c_row79_col0, #T_3dd9c_row80_col0, #T_3dd9c_row81_col0, #T_3dd9c_row82_col0, #T_3dd9c_row83_col0, #T_3dd9c_row83_col3, #T_3dd9c_row84_col0, #T_3dd9c_row85_col0, #T_3dd9c_row86_col0, #T_3dd9c_row87_col0, #T_3dd9c_row88_col0, #T_3dd9c_row88_col3, #T_3dd9c_row89_col0, #T_3dd9c_row90_col0, #T_3dd9c_row90_col1, #T_3dd9c_row91_col0, #T_3dd9c_row91_col1, #T_3dd9c_row92_col0, #T_3dd9c_row92_col1, #T_3dd9c_row93_col0, #T_3dd9c_row93_col1, #T_3dd9c_row93_col3, #T_3dd9c_row94_col0, #T_3dd9c_row94_col1, #T_3dd9c_row95_col0, #T_3dd9c_row95_col1, #T_3dd9c_row95_col2, #T_3dd9c_row95_col7, #T_3dd9c_row96_col0, #T_3dd9c_row96_col1, #T_3dd9c_row96_col2, #T_3dd9c_row96_col7, #T_3dd9c_row97_col0, #T_3dd9c_row97_col1, #T_3dd9c_row97_col2, #T_3dd9c_row97_col7, #T_3dd9c_row98_col0, #T_3dd9c_row98_col1, #T_3dd9c_row98_col2, #T_3dd9c_row98_col3, #T_3dd9c_row98_col4, #T_3dd9c_row98_col5, #T_3dd9c_row98_col6, #T_3dd9c_row98_col7, #T_3dd9c_row98_col8, #T_3dd9c_row98_col9, #T_3dd9c_row98_col10, #T_3dd9c_row98_col11, #T_3dd9c_row98_col12, #T_3dd9c_row98_col13, #T_3dd9c_row98_col14, #T_3dd9c_row98_col15, #T_3dd9c_row98_col16, #T_3dd9c_row98_col17, #T_3dd9c_row99_col0, #T_3dd9c_row99_col1, #T_3dd9c_row99_col2, #T_3dd9c_row99_col7, #T_3dd9c_row100_col0, #T_3dd9c_row100_col1, #T_3dd9c_row101_col0, #T_3dd9c_row101_col1, #T_3dd9c_row102_col0, #T_3dd9c_row102_col1, #T_3dd9c_row103_col0, #T_3dd9c_row103_col1, #T_3dd9c_row103_col3, #T_3dd9c_row104_col0, #T_3dd9c_row104_col1, #T_3dd9c_row105_col0, #T_3dd9c_row105_col1, #T_3dd9c_row106_col0, #T_3dd9c_row106_col1, #T_3dd9c_row107_col0, #T_3dd9c_row107_col1, #T_3dd9c_row108_col0, #T_3dd9c_row108_col1, #T_3dd9c_row108_col3, #T_3dd9c_row109_col0, #T_3dd9c_row109_col ...
#   font-weight: bold;
# }
# #T_3dd9c_row5_col14, #T_3dd9c_row29_col15, #T_3dd9c_row45_col13, #T_3dd9c_row48_col11, #T_3dd9c_row50_col10, #T_3dd9c_row89_col15, #T_3dd9c_row100_col12, #T_3dd9c_row115_col16, #T_3dd9c_row115_col17 {
#   background: yellow;
# }
# #T_3dd9c_row21_col7, #T_3dd9c_row29_col4, #T_3dd9c_row71_col5, #T_3dd9c_row71_col8, #T_3dd9c_row71_col9, #T_3dd9c_row115_col6 {
#   background-color: lightgreen;
# }
# #T_3dd9c_row98_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_3dd9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dd9c_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_3dd9c_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_3dd9c_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_3dd9c_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_3dd9c_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_3dd9c_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_3dd9c_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_3dd9c_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_3dd9c_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_3dd9c_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_3dd9c_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_3dd9c_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_3dd9c_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_3dd9c_level0_col13" class="col_heading level0 col13" >avg_ford_score</th>
#       <th id="T_3dd9c_level0_col14" class="col_heading level0 col14" >avg_ppvd_score</th>
#       <th id="T_3dd9c_level0_col15" class="col_heading level0 col15" >avg_(1-consistency_score)</th>
#       <th id="T_3dd9c_level0_col16" class="col_heading level0 col16" >avg_gei_score</th>
#       <th id="T_3dd9c_level0_col17" class="col_heading level0 col17" >avg_ti_score</th>
#       <th id="T_3dd9c_level0_col18" class="col_heading level0 col18" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dd9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dd9c_row0_col0" class="data row0 col0" >TabTrans</td>
#       <td id="T_3dd9c_row0_col1" class="data row0 col1" >{'epochs': 20, 'learing_rate': 0.0001}</td>
#       <td id="T_3dd9c_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_3dd9c_row0_col3" class="data row0 col3" >0.300000</td>
#       <td id="T_3dd9c_row0_col4" class="data row0 col4" >0.453000</td>
#       <td id="T_3dd9c_row0_col5" class="data row0 col5" >0.495383</td>
#       <td id="T_3dd9c_row0_col6" class="data row0 col6" >0.375037</td>
#       <td id="T_3dd9c_row0_col7" class="data row0 col7" >0.516574</td>
#       <td id="T_3dd9c_row0_col8" class="data row0 col8" >-0.010323</td>
#       <td id="T_3dd9c_row0_col9" class="data row0 col9" >0.494839</td>
#       <td id="T_3dd9c_row0_col10" class="data row0 col10" >-0.012120</td>
#       <td id="T_3dd9c_row0_col11" class="data row0 col11" >-0.015140</td>
#       <td id="T_3dd9c_row0_col12" class="data row0 col12" >-0.007647</td>
#       <td id="T_3dd9c_row0_col13" class="data row0 col13" >-0.115755</td>
#       <td id="T_3dd9c_row0_col14" class="data row0 col14" >0.063725</td>
#       <td id="T_
