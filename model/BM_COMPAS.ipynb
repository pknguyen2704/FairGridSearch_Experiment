# %% [markdown]
# # Bias Mitigation Experiments - COMPAS

# %%
data_name = 'Compas'

# %%
# to ignore warnings
import warnings
# warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
# tf.disable_eager_execution() # comment out when running TabTransformer models

# %% [markdown]
# ## [1.](#Table-of-Contents) Prepare COMPAS data

# %%
# read in data as pandas data frame
df = pd.read_csv("../data/Compas/compas-scores-two-years.csv")
# check columns
pd.set_option('display.max_columns', None) # expand all columns
print(df.shape)
df.head()
# Out:
# (7214, 53)
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1991-05-14   24     Less than 25  African-American              0
# 3  1993-01-21   23     Less than 25  African-American              0
# 4  1973-01-22   43          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0             1               0                0             0
# 1             3               0                0             0
# 2             4               0                1             4
# 3             8               1                0             1
# 4             1               0                0             2
#
#    days_b_screening_arrest            c_jail_in           c_jail_out  \
# 0                     -1.0  2013-08-13 06:03:42  2013-08-14 05:41:20
# 1                     -1.0  2013-01-26 03:45:27  2013-02-05 05:36:53
# 2                     -1.0  2013-04-13 04:58:34  2013-04-14 07:02:04
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
#    c_case_number c_offense_date c_arrest_date  c_days_from_compas  \
# 0  13011352CF10A     2013-08-13           NaN                 1.0
# 1  13001275CF10A     2013-01-26           NaN                 1.0
# 2  13005330CF10A     2013-04-13           NaN                 1.0
# 3  13000570CF10A     2013-01-12           NaN                 1.0
# 4  12014130CF10A            NaN    2013-01-09                76.0
#
#   c_charge_degree                   c_charge_desc  is_recid  r_case_number  \
# 0               F    Aggravated Assault w/Firearm         0            NaN
# 1               F  Felony Battery w/Prior Convict         1  13009779CF10A
# 2               F           Possession of Cocaine         1  13011511MM10A
# 3               F          Possession of Cannabis         0            NaN
# 4               F           arrest case no charge         0            NaN
#
#   r_charge_degree  r_days_from_arrest r_offense_date  \
# 0             NaN                 NaN            NaN
# 1            (F3)                 NaN     2013-07-05
# 2            (M1)                 0.0     2013-06-16
# 3             NaN                 NaN            NaN
# 4             NaN                 NaN            NaN
#
#                  r_charge_desc   r_jail_in  r_jail_out  violent_recid  \
# 0                          NaN         NaN         NaN            NaN
# 1  Felony Battery (Dom Strang)         NaN         NaN            NaN
# 2  Driving Under The Influence  2013-06-16  2013-06-16            NaN
# 3                          NaN         NaN         NaN            NaN
# 4                          NaN         NaN         NaN            NaN
#
#    is_violent_recid vr_case_number vr_charge_degree vr_offense_date  \
# 0                 0            NaN              NaN             NaN
# 1                 1  13009779CF10A             (F3)      2013-07-05
# 2                 0            NaN              NaN             NaN
# 3                 0            NaN              NaN             NaN
# 4                 0            NaN              NaN             NaN
#
#                 vr_charge_desc  type_of_assessment  decile_score.1 score_text  \
# 0                          NaN  Risk of Recidivism               1        Low
# 1  Felony Battery (Dom Strang)  Risk of Recidivism               3        Low
# 2                          NaN  Risk of Recidivism               4        Low
# 3                          NaN  Risk of Recidivism               8       High
# 4                          NaN  Risk of Recidivism               1        Low
#
#   screening_date v_type_of_assessment  v_decile_score v_score_text  \
# 0     2013-08-14     Risk of Violence               1          Low
# 1     2013-01-27     Risk of Violence               1          Low
# 2     2013-04-14     Risk of Violence               3          Low
# 3     2013-01-13     Risk of Violence               6       Medium
# 4     2013-03-26     Risk of Violence               1          Low
#
#   v_screening_date  in_custody out_custody  priors_count.1  start   end  \
# 0       2013-08-14  2014-07-07  2014-07-14               0      0   327
# 1       2013-01-27  2013-01-26  2013-02-05               0      9   159
# 2       2013-04-14  2013-06-16  2013-06-16               4      0    63
# 3       2013-01-13         NaN         NaN               1      0  1174
# 4       2013-03-26         NaN         NaN               2      0  1102
#
#    event  two_year_recid
# 0      0               0
# 1      1               1
# 2      0               1
# 3      0               0
# 4      0               0

# %%
df['race'].value_counts()
# Out:
# African-American    3696
# Caucasian           2454
# Hispanic             637
# Other                377
# Asian                 32
# Native American       18
# Name: race, dtype: int64

# %%
# data pre-processing
import re
label = 'two_year_recid'
protected_attribute = 'race'
# 1. select features of interest
keep_var = ['sex','age','race','juv_fel_count','juv_misd_count','juv_other_count','priors_count',
            'c_charge_degree', 'two_year_recid']
df = df[keep_var]

# 2. encode label and potential protected features 
race_mapping = {'Caucasian': 1, 'African-American': 0}
sex_mapping = {'Female': 1, 'Male': 0} # female is the privileged group in this case

df = df[df.race.isin(race_mapping.keys())] # only include samples with certain race values
df.race.replace(race_mapping, inplace=True)
df.sex.replace(sex_mapping, inplace=True)
df = df.reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (6150, 9)
#    sex  age  race  juv_fel_count  juv_misd_count  juv_other_count  \
# 0    0   34     0              0               0                0
# 1    0   24     0              0               0                1
# 2    0   23     0              0               1                0
# 3    0   41     1              0               0                0
# 4    1   39     1              0               0                0
#
#    priors_count c_charge_degree  two_year_recid
# 0             0               F               1
# 1             4               F               1
# 2             1               F               0
# 3            14               F               1
# 4             0               M               0

# %%
# flip labels to ensure pos_label = 1, not becoming recidivist
df[label] = (~df[label].astype(bool)).astype(int)

# select descriptive features and target variable
X = df.drop(columns=label, axis=1) # select all features but target feature
y = df[[protected_attribute, label]] # include protected feature in order to AIF360

# %%
# set protected attribute as index
X = X.set_index([protected_attribute], append = True, drop = False)
y = y.set_index([protected_attribute], append = True)

# make y data frames to 1d array to pass modeling, but keep index (protected attribute)
y = pd.Series(y[label], index=y.index)

# %%
X.to_pickle('../data/{}/{}_X'.format(data_name, data_name))
y.to_pickle('../data/{}/{}_y'.format(data_name, data_name))

# %% [markdown]
# ## [2.](#Table-of-Contents) Proposed GridSearch Approach

# %% [markdown]
# The GridSearch Approach includes hyperparameter, threshold, and Bias Mitigation

# %%
from FairGridSearch import *
# %load_ext autoreload
# %autoreload 2
# allow automatic reloading of changes in FairGridSearch file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# None, better
# 'RW', worse
# 'LFR_pre', stuck
# 'LFR_in', stuck
# 'AD', stuck
# 'EGR',better
# 'ROC', better
# 'CEO', better

# %% [markdown]
# ## 3. Case Study: COMPAS

# %%
label = 'two_year_recid'
protected_attribute = 'race'

pos_label = 0
priv_group = 1

cv=10
n_jobs=multiprocessing.cpu_count()-1

# %%
X = pd.read_pickle('../data/{}/{}_X'.format(data_name, data_name))
y = pd.read_pickle('../data/{}/{}_y'.format(data_name, data_name))

# %%
# define desired metric for the use case
ACC_METRIC = 'avg_norm_mcc_score'
FAIR_METRIC = 'abs_avg_ppvd_score'

# %% [markdown]
# ### Logistic Regression

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'C':[1, 10],'solver':['liblinear', 'saga'],'penalty':['l2']}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','LFR_in','AD','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_lr = fair_GridsearchCV(base='LR', param_grid=param_grid, 
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_lr.fit(X=X, y=y)
    
results_lr = clf_lr.output_table
print(clf_lr._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_lr.to_pickle('./{}_results/{}_results_LR'.format(data_name,data_name))
style_table(results_lr)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [01:01<03:05, 61.93s/it]
# {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [02:10<02:12, 66.07s/it]
# {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [03:15<01:05, 65.62s/it]
# {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [04:16<00:00, 64.07s/it]
# base_estimator                                                   LR
# param              {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Bias_Mitigation                                                  AD
# threshold                                                       0.6
# Name: 23, dtype: object
# Time:  4.27735883 min
# <style type="text/css">
# #T_2bbad_row0_col0, #T_2bbad_row0_col1, #T_2bbad_row1_col0, #T_2bbad_row1_col1, #T_2bbad_row2_col0, #T_2bbad_row2_col1, #T_2bbad_row3_col0, #T_2bbad_row3_col1, #T_2bbad_row3_col3, #T_2bbad_row4_col0, #T_2bbad_row4_col1, #T_2bbad_row5_col0, #T_2bbad_row5_col1, #T_2bbad_row6_col0, #T_2bbad_row6_col1, #T_2bbad_row7_col0, #T_2bbad_row7_col1, #T_2bbad_row8_col0, #T_2bbad_row8_col1, #T_2bbad_row8_col3, #T_2bbad_row9_col0, #T_2bbad_row9_col1, #T_2bbad_row10_col0, #T_2bbad_row10_col1, #T_2bbad_row11_col0, #T_2bbad_row11_col1, #T_2bbad_row12_col0, #T_2bbad_row12_col1, #T_2bbad_row13_col0, #T_2bbad_row13_col1, #T_2bbad_row13_col3, #T_2bbad_row14_col0, #T_2bbad_row14_col1, #T_2bbad_row15_col0, #T_2bbad_row15_col1, #T_2bbad_row16_col0, #T_2bbad_row16_col1, #T_2bbad_row17_col0, #T_2bbad_row17_col1, #T_2bbad_row18_col0, #T_2bbad_row18_col1, #T_2bbad_row18_col3, #T_2bbad_row19_col0, #T_2bbad_row19_col1, #T_2bbad_row20_col0, #T_2bbad_row20_col1, #T_2bbad_row20_col2, #T_2bbad_row20_col7, #T_2bbad_row21_col0, #T_2bbad_row21_col1, #T_2bbad_row21_col2, #T_2bbad_row21_col7, #T_2bbad_row22_col0, #T_2bbad_row22_col1, #T_2bbad_row22_col2, #T_2bbad_row22_col7,
bbad_row73_col2, #T_2bbad_row73_col3, #T_2bbad_row73_col4, #T_2bbad_row73_col5, #T_2bbad_row73_col6, #T_2bbad_row73_col7, #T_2bbad_row73_col8, #T_2bbad_row73_col9, #T_2bbad_row73_col10, #T_2bbad_row73_col11, #T_2bbad_row73_col12, #T_2bbad_row73_col13, #T_2bbad_row73_col14, #T_2bbad_row73_col15, #T_2bbad_row73_col16, #T_2bbad_row73_col17, #T_2bbad_row74_col0, #T_2bbad_row74_col2, #T_2bbad_row74_col7, #T_2bbad_row75_col0, #T_2bbad_row76_col0, #T_2bbad_row77_col0, #T_2bbad_row78_col0, #T_2bbad_row78_c ...

# %% [markdown]
# ### Random Forest

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'n_estimators':[10, 50],'criterion':['gini', 'entropy'], 'max_depth':[16]}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_rf = fair_GridsearchCV(base='RF', param_grid=param_grid,
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_rf.fit(X=X, y=y)
    
results_rf = clf_rf.output_table
print(clf_rf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_rf.to_pickle('./{}_results/{}_results_RF'.format(data_name, data_name))
style_table(results_rf)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'criterion': 'gini', 'max_depth': 16, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:41<02:04, 41.62s/it]
# {'criterion': 'gini', 'max_depth': 16, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [01:47<01:51, 55.95s/it]
# {'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [02:39<00:54, 54.25s/it]
# {'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [04:02<00:00, 60.72s/it]
# base_estimator                                                    RF
# param              {'criterion': 'entropy', 'max_depth': 16, 'n_e...
# Bias_Mitigation                                               RW+CEO
# threshold                                                        0.4
# Name: 116, dtype: object
# Time:  4.056987171666667 min
# <style type="text/css">
# #T_67e98_row0_col0, #T_67e98_row1_col0, #T_67e98_row1_col3, #T_67e98_row2_col0, #T_67e98_row3_col0, #T_67e98_row4_col0, #T_67e98_row5_col0, #T_67e98_row6_col0, #T_67e98_row6_col3, #T_67e98_row7_col0, #T_67e98_row8_col0, #T_67e98_row9_col0, #T_67e98_row10_col0, #T_67e98_row11_col0, #T_67e98_row11_col3, #T_67e98_row12_col0, #T_67e98_row13_col0, #T_67e98_row14_col0, #T_67e98_row15_col0, #T_67e98_row16_col0, #T_67e98_row16_col3, #T_67e98_row17_col0, #T_67e98_row18_col0, #T_67e98_row19_col0, #T_67e98_row20_col0, #T_67e98_row21_col0, #T_67e98_row21_col3, #T_67e98_row22_col0, #T_67e98_row23_col0, #T_67e98_row24_col0, #T_67e98_row25_col0, #T_67e98_row26_col0, #T_67e98_row26_col3, #T_67e98_row27_col0, #T_67e98_row28_col0, #T_67e98_row29_col0, #T_67e98_row30_col0, #T_67e98_row31_col0, #T_67e98_row31_col3, #T_67e98_row32_col0, #T_67e98_row33_col0, #T_67e98_row34_col0, #T_67e98_row35_col0, #T_67e98_row35_col2, #T_67e98_row36_col0, #T_67e98_row36_col2, #T_67e98_row36_col3, #T_67e98_row37_col0, #T_67e98_row37_col2, #T_67e98_row38_col0, #T_67e98_row38_col2, #T_67e98_row39_col0, #T_67e98_row39_col2, #T_67e98_row40_col0, #T_67e98_row41_col0, #T_67e98_row41_col3, #T_67e98_row42_col0, #T_67e98_row43_col0, #T_67e98_row44_col0, #T_67e98_row45_col0, #T_67e98_row46_col0, #T_67e98_row46_col3, #T_67e98_row47_col0, #T_67e98_row48_col0, #T_67e98_row49_col0, #T_67e98_row50_col0, #T_67e98_row51_col0, #T_67e98_row51_col3, #T_67e98_row52_col0, #T_67e98_row53_col0, #T_67e98_row54_col0, #T_67e98_row55_col0, #T_67e98_row56_col0, #T_67e98_row56_col3, #T_67e98_row57_col0, #T_67e98_row58_col0, #T_67e98_row59_col0, #T_67e98_row60_col0, #T_67e98_row61_col0, #T_67e98_row61_col3, #T_67e98_row62_col0, #T_67e98_row63_col0, #T_67e98_row64_col0, #T_67e98_row65_col0, #T_67e98_row66_col0, #T_67e98_row66_col3, #T_67e98_row67_col0, #T_67e98_row68_col0, #T_67e98_row69_col0, #T_67e98_row70_col0, #T_67e98_row71_col0, #T_67e98_row71_col3, #T_67e98_row72_col0, #T_67e98_row73_col0, #T_67e98_row74_col0, #T_67e98_row75_col0, #T_67e98_row75_col2, #T_67e98_row76_col0, #T_67e98_row76_col2, #T_67e98_row76_col3, #T_67e98_row77_col0, #T_67e98_row77_col2, #T_67e98_row78_col0, #T_67e98_row78_col2, #T_67e98_row79_col0, #T_67e98_row79_col2, #T_67e98_row80_col0, #T_67e98_row80_col1, #T_67e98_row81_col0, #T_67e98_row81_col1, #T_67e98_row81_col3, #T_67e98_row82_col0, #T_67e98_row82_col1, #T_67e98_row83_col0, #T_67e98_row83_col1, #T_67e98_row84_col0, #T_67e98_row84_col1, #T_67e98_row85_col0, #T_67e98_row85_col1, #T_67e98_row86_col0, #T_67e98_row86_col1, #T_67e98_row86_col3, #T_67e98_row87_col0, #T_67e98_row87_col1, #T_67e98_row88_col0, #T_67e98_row88_col1, #T_67e98_row89_col0, #T_67e98_row89_col1, #T_67e98_row90_col0, #T_67e98_row90_col1, #T_67e98_row91_col0, #T_67e98_row91_col1, #T_67e98_row91_col3, #T_67e98_row92_col0, #T_67e98_row92_col1, #T_67e98_row93_col0, #T_67e98_row93_col1, #T_67e98_row94_col0, #T_67e98_row94_col1, #T_67e98_row95_col0, #T_67e98_row95_col1, #T_67e98_row96_col0, #T_67e98_row96_col1, #T_67e98_row96_col3, #T_67e98_row97_col0, #T_67e98_row97_col1, #T_67e98_row98_col0, #T_67e98_row98_col1, #T_67e98_row99_col0, #T_67e98_row99_col1, #T_67e98_row100_col0, #T_67e98_row100_col1, #T_67e98_row101_col0, #T_67e98_row101_col1, #T_67e98_row101_col3, #T_67e98_row102_col0, #T_67e98_row102_col1, #T_67e98_row103_col0, #T_67e98_row103_col1, #T_67e98_row104_col0, #T_67e98_row104_col1, #T_67e98_row105_col0, #T_67e98_row105_col1, #T_67e98_row106_col0, #T_67e98_row106_col1, #T_67e98_row106_col3, #T_67e98_row107_col0, #T_67e98_row107_col1, #T_67e98_row108_col0, #T_67e98_row108_col1, #T_67e98_row109_col0, #T_67e98_row109_col1, #T_67e98_row110_col0, #T_67e98_row110_col1, #T_67e98_row111_col0, #T_67e98_row111_col1, #T_67e98_row111_col3, #T_67e98_row112_col0, #T_67e98_row112_col1, #T_67e98_row113_col0, #T_67e98_row113_col1, #T_67e98_row114_col0, #T_67e98_row114_col1, #T_67e98_row115_col0, #T_67e98_row115_col1, #T_67e98_row115_col2, #T_67e98_row115_col7, #T_67e98_row116_col0, #T_67e98_row116_col1, #T_6 ...
#   font-weight: bold;
# }
# #T_67e98_row51_col14, #T_67e98_row54_col15, #T_67e98_row102_col13, #T_67e98_row130_col16, #T_67e98_row130_col17, #T_67e98_row134_col10, #T_67e98_row134_col11, #T_67e98_row134_col12 {
#   background: yellow;
# }
# #T_67e98_row116_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# #T_67e98_row120_col6, #T_67e98_row121_col4, #T_67e98_row140_col6, #T_67e98_row141_col4, #T_67e98_row142_col5, #T_67e98_row142_col7, #T_67e98_row142_col8, #T_67e98_row142_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_67e98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67e98_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_67e98_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_67e98_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_67e98_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_67e98_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_67e98_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_67e98_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_67e98_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_67e98_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_67e98_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_67e98_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_67e98_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_67e98_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_67e98_level0_col13" class="col_heading level0 col13" >avg_ford_score</th>
#       <th id="T_67e98_level0_col14" class="col_heading level0 col14" >avg_ppvd_score</th>
#       <th id="T_67e98_level0_col15" class="col_heading level0 col15" >avg_(1-consistency_score)</th>
#       <th id="T_67e98_level0_col16" class="col_heading level0 col16" >avg_gei_score</th>
#       <th id="T_67e98_level0_col17" class="col_heading level0 col17" >avg_

# %% [markdown]
# ### Gradient Boosting

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'n_estimators':[10, 50],'criterion':['friedman_mse'],'max_depth':[8, 32]}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_gb = fair_GridsearchCV(base='GB', param_grid=param_grid,
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_gb.fit(X=X, y=y)
    
results_gb = clf_gb.output_table
print(clf_gb._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_gb.to_pickle('./{}_results/{}_results_GB'.format(data_name, data_name))
style_table(results_gb)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'criterion': 'friedman_mse', 'max_depth': 8, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:55<02:45, 55.18s/it]
# {'criterion': 'friedman_mse', 'max_depth': 8, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [02:31<02:38, 79.34s/it]
# {'criterion': 'friedman_mse', 'max_depth': 32, 'n_estimators': 10}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [03:58<01:23, 83.07s/it]
# {'criterion': 'friedman_mse', 'max_depth': 32, 'n_estimators': 50}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [08:43<00:00, 130.81s/it]
# base_estimator                                                    GB
# param              {'criterion': 'friedman_mse', 'max_depth': 8, ...
# Bias_Mitigation                                                   RW
# threshold                                                        0.6
# Name: 8, dtype: object
# Time:  8.725093631666663 min
# <style type="text/css">
# #T_c3f9c_row0_col0, #T_c3f9c_row0_col1, #T_c3f9c_row1_col0, #T_c3f9c_row1_col1, #T_c3f9c_row2_col0, #T_c3f9c_row2_col1, #T_c3f9c_row3_col0, #T_c3f9c_row3_col1, #T_c3f9c_row3_col3, #T_c3f9c_row4_col0, #T_c3f9c_row4_col1, #T_c3f9c_row5_col0, #T_c3f9c_row5_col1, #T_c3f9c_row5_col2, #T_c3f9c_row5_col7, #T_c3f9c_row6_col0, #T_c3f9c_row6_col1, #T_c3f9c_row6_col2, #T_c3f9c_row6_col7, #T_c3f9c_row7_col0, #T_c3f9c_row7_col1, #T_c3f9c_row7_col2, #T_c3f9c_row7_col7, #T_c3f9c_row8_col0, #T_c3f9c_row8_col1, #T_c3f9c_row8_col2, #T_c3f9c_row8_col3, #T_c3f9c_row8_col4, #T_c3f9c_row8_col5, #T_c3f
3f9c_row47_col2, #T_c3f9c_row48_col0, #T_c3f9c_row48_col2, #T_c3f9c_row48_col3, #T_c3f9c_row49_col0, #T_c3f9c_row49_col2, #T_c3f9c_row50_col0, #T_c3f9c_row51_col0, #T_c3f9c_row52_col0, #T_c3f9c_row53_col0, #T_c3f9c_row53_col3, #T_c3f9c_row54_col0, #T_c3f9c_row55_col0, #T_c3f9c_row56_col0, #T_c3f9c_row57_col0, #T_c3f9c_row58_col0, #T_c3f9c_row58_col3, #T_c3f9c_row59_col0, #T_c3f9c_row60_col0, #T_c3f9c_row61_col0, #T_c3f9c_row62_col0, #T_c3f9c_row63_col0, #T_c3f9c_row63_col3, #T_c3f9c_row64_col0, #T_c3f9c_row65_col0, #T_c3f9c_row66_col0, #T_c3f9c_row67_col0, #T_c3f9c_row68_col0, #T_c3f9c_row68_col3, #T_c3f9c_row69_col0, #T_c3f9c_row70_col0, #T_c3f9c_row71_col0, #T_c3f9c_row72_col0, #T_c3f9c_row73_col0, #T_c3f9c_row73_col3, #T_c3f9c_row74_col0, #T_c3f9c_row75_col0, #T_c3f9c_row76_col0, #T_c3f9c_row77_col0, #T_c3f9c_row78_col0, #T_c3f9c_row78_col3, #T_c3f9c_row79_col0, #T_c3f9c_row80_col0, #T_c3f9c_row81_col0, #T_c3f9c_row82_col0, #T_c3f9c_row83_col0, #T_c3f9c_row83_col3, #T_c3f9c_row84_col0, #T_c3f9c_row85_col0, #T_c3f9c_row85_col2, #T_c3f9c_row86_col0, #T_c3f9c_row86_col2, #T_c3f9c_row87_col0, #T_c3f9c_row87_col2, #T_c3f9c_row88_col0, #T_c3f9c_row88_col2, #T_c3f9c_row88_col3, #T_c3f9c_row89_col0, #T_c3f9c_row89_col2 ...
#   font-weight: bold;
# }
# #T_c3f9c_row1_col6, #T_c3f9c_row2_col4, #T_c3f9c_row2_col5, #T_c3f9c_row2_col8, #T_c3f9c_row2_col9, #T_c3f9c_row21_col6, #T_c3f9c_row24_col7 {
#   background-color: lightgreen;
# }
# #T_c3f9c_row8_col12, #T_c3f9c_row33_col12 {
#   background: yellow;
#   font-weight: bold;
# }
# #T_c3f9c_row8_col18, #T_c3f9c_row33_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# #T_c3f9c_row10_col15, #T_c3f9c_row32_col14, #T_c3f9c_row35_col16, #T_c3f9c_row35_col17, #T_c3f9c_row49_col10, #T_c3f9c_row72_col13, #T_c3f9c_row74_col10, #T_c3f9c_row156_col11 {
#   background: yellow;
# }
# </style>
# <table id="T_c3f9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3f9c_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_c3f9c_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_c3f9c_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_c3f9c_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_c3f9c_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_c3f9c_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_c3f9c_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_c3f9c_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_c3f9c_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_c3f9c_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_c3f9c_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_c3f9c_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_c3f9c_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_c3f9c_level0_col13" class="col_heading level0 col13" >avg_ford_score</th>
#       <th id="T_c3f9c_level0_col14" class="col_heading level0 col14" >avg_ppvd_score</th>
#       <th id="T_c3f9c_level0_col

# %% [markdown]
# ### Support Vector Machine

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'kernel':['rbf','linear','poly','sigmoid'],'gamma':['scale']},
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_svm = fair_GridsearchCV(base='SVM', param_grid=param_grid,
                            prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                            cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_svm.fit(X=X, y=y)
    
results_svm = clf_svm.output_table
print(clf_svm._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results
# #T_83f46_row10_col10, #T_83f46_row10_col11, #T_83f46_row10_col12, #T_83f46_row10_col15, #T_83f46_row11_col10, #T_83f46_row11_col11, #T_83f46_row11_col12, #T_83f46_row11_col13, #T_83f46_row11_col15, #T_83f46_row12_col10, #T_83f46_row12_col11, #T_83f46_row12_col12, #T_83f46_row12_col13, #T_83f46_row12_col15, #T_83f46_row13_col10, #T_83f46_row13_col11, #T_83f46_row13_col12, #T_83f46_row13_col13, #T_83f46_row13_col15, #T_83f46_row14_col10, #T_83f46_row14_col11, #T_83f46_row14_col12, #T_83f46_row14_col13, #T_83f46_row14_col15, #T_83f46_row130_col10, #T_83f46_row130_col11, #T_83f46_row130_col12, #T_83f46_row130_col14, #T_83f46_row130_col15, #T_83f46_row130_col16, #T_83f46_row130_col17, #T_83f46_row131_col10, #T_83f46_row131_col11, #T_83f46_row131_col12, #T_83f46_row131_col14, #T_83f46_row131_col15, #T_83f46_row131_col16, #T_83f46_row131_col17, #T_83f46_row132_col10, #T_83f46_row132_col11, #T_83f46_row132_col12, #T_83f46_row132_col14, #T_83f46_row132_col15, #T_83f46_row132_col16, #T_83f46_row132_col17, #T_83f46_row133_col10, #T_83f46_row133_col11, #T_83f46_row133_col12, #T_83f46_row133_col13, #T_83f46_row133_col15, #T_83f46_row134_col10, #T_83f46_row134_col11, #T_83f46_row134_col12, #T_83f46_row134_col13, #T_83f46_row134_col15 {
#   background: yellow;
# }
# #T_83f46_row47_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_83f46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83f46_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_83f46_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_83f46_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_83f46_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_83f46_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_83f46_level

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
# model for Reweighing
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'var_smoothing': np.logspace(0,-9, num=4)}, 
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','LFR_pre','EGR','ROC','CEO','RW+ROC','RW+CEO']}

clf_nb = fair_GridsearchCV(base='NB', param_grid=param_grid, 
                           prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                           cv=cv, n_jobs=n_jobs)
if __name__ == '__main__':
    clf_nb.fit(X=X, y=y)
    
results_nb = clf_nb.output_table
# print(clf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_nb.to_pickle('./{}_results/{}_results_NB'.format(data_name, data_name))
style_table(results_nb)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'var_smoothing': 1.0}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [00:34<01:42, 34.21s/it]
# {'var_smoothing': 0.001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [01:07<01:07, 33.52s/it]
# {'var_smoothing': 1e-06}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [01:40<00:33, 33.50s/it]
# {'var_smoothing': 1e-09}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [02:13<00:00, 33.26s/it]
# Time:  2.22212151666666 min
# <style type="text/css">
# #T_8851d_row0_col0, #T_8851d_row0_col1, #T_8851d_row1_col0, #T_8851d_row1_col1, #T_8851d_row2_col0, #T_8851d_row2_col1, #T_8851d_row3_col0, #T_8851d_row3_col1, #T_8851d_row4_col0, #T_8851d_row4_col1, #T_8851d_row4_col3, #T_8851d_row5_col0, #T_8851d_row5_col1, #T_8851d_row6_col0, #T_8851d_row6_col1, #T_8851d_row7_col0, #T_8851d_row7_col1, #T_8851d_row8_col0, #T_8851d_row8_col1, #T_8851d_row9_col0, #T_8851d_row9_col1, #T_8851d_row9_col3, #T_8851d_row10_col0, #T_8851d_row10_col1, #T_8851d_row11_col0, #T_8851d_row11_col1, #T_8851d_row12_col0, #T_8851d_row12_col1, #T_8851d_row13_col0, #T_8851d_row13_col1, #T_8851d_row14_col0, #T_8851d_row14_col1, #T_8851d_row14_col3,
0, #T_8851d_row72_col0, #T_8851d_row73_col0, #T_8851d_row74_col0, #T_8851d_row74_col3, #T_8851d_row75_col0, #T_8851d_row76_col0, #T_8851d_row77_col0, #T_8851d_row78_col0, #T_8851d_row79_col0, #T_8851d_row79_col3, #T_8851d_row80_col0, #T_8851d_row81_col0, #T_8851d_row82_col0, #T_8851d_row83_col0, #T_8851d_row84_col0, #T_8851d_row84_col3, #T_8851d_row85_col0, #T_8851d_row86_col0, #T_8851d_row87_col0, #T_8851d_row88_col0, #T_8851d_row89_col0, #T_8851d_row89_col3, #T_8851d_row90_col0, #T_8851d_row91_col0, #T_8851d_row92_col0, #T_8851d_row93_col0, #T_8851d_row94_col0, #T_8851d_row94_col3, #T_8851d_row95_col0, #T_8851d_row96_col0, #T_8851d_row97_col0, #T_8851d_row98_col0, #T_8851d_row99_col0, #T_8851d_row99_col3, #T_8851d_row100_col0, #T_8851d_row101_col0, #T_8851d_row102_col0, #T_8851d_row103_col0,  ...
#   font-weight: bold;
# }
# #T_8851d_row3_col6, #T_8851d_row4_col4, #T_8851d_row4_col5, #T_8851d_row4_col8, #T_8851d_row4_col9, #T_8851d_row23_col6, #T_8851d_row24_col4, #T_8851d_row24_col5, #T_8851d_row24_col8, #T_8851d_row24_col9, #T_8851d_row32_col7 {
#   background-color: lightgreen;
# }
# #T_8851d_row4_col13, #T_8851d_row12_col10, #T_8851d_row15_col16, #T_8851d_row15_col17, #T_8851d_row16_col16, #T_8851d_row16_col17, #T_8851d_row24_col13, #T_8851d_row58_col12, #T_8851d_row58_col15, #T_8851d_row59_col12, #T_8851d_row59_col15, #T_8851d_row95_col14, #T_8851d_row96_col14, #T_8851d_row98_col12, #T_8851d_row98_col15, #T_8851d_row99_col12, #T_8851d_row99_col15, #T_8851d_row135_col14, #T_8851d_row136_col14, #T_8851d_row138_col12, #T_8851d_row138_col15, #T_8851d_row139_col12, #T_8851d_row139_col15 {
#   background: yellow;
# }
# #T_8851d_row29_col11 {
#   background: yellow;
#   font-weight: bold;
# }
# #T_8851d_row29_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_8851d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8851d_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_8851d_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_8851d_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_8851d_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_8851d_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_8851d_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_8851d_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_8851d_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_8851d_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_8851d_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_8851d_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_8851d_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_8851d_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_8851d_level0_col13" class="col_heading level0 col13"

# %% [markdown]
# ### TabTransformer

# %%
import timeit
start = timeit.default_timer()

param_grid = {'hyperp_grid': {'epochs':[20, 30],'learing_rate':[1e-04, 1e-05]},
              'threshold': np.linspace(0.3, 0.7, 5),
              'Bias_Mitigation':[None,'RW','ROC','CEO','RW+ROC','RW+CEO']}

clf_tab = fair_GridsearchCV(base='TabTrans',param_grid=param_grid, 
                            prot_attr=protected_attribute, pos_label=pos_label, priv_group=priv_group,
                            cv=cv, n_jobs=n_jobs)

clf_tab.fit(X=X, y=y)
results_tab = clf_tab.output_table
# print(clf._best_param)

stop = timeit.default_timer()
runtime = stop - start
if runtime < 60:
    print('Time: ', runtime, 'sec')
else: print('Time: ', runtime/60, 'min')
results_tab.to_pickle('./{}_results/{}_results_TabTrans'.format(data_name, data_name))

style_table(results_tab)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'epochs': 20, 'learing_rate': 0.0001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  25%|██▌       | 1/4 [05:02<15:06, 302.06s/it]
# {'epochs': 20, 'learing_rate': 1e-05}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  50%|█████     | 2/4 [09:53<09:51, 295.74s/it]
# {'epochs': 30, 'learing_rate': 0.0001}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
#  75%|███████▌  | 3/4 [15:36<05:17, 317.41s/it]
# {'epochs': 30, 'learing_rate': 1e-05}
# ------------------------------------------------------------------------------------------
# start multiprocessing
# ------------------------------------------------------------------------------------------
# 100%|██████████| 4/4 [21:58<00:00, 329.68s/it]
# Time:  21.990890648333334 min
# <style type="text/css">
# #T_b21b1_row0_col0, #T_b21b1_row1_col0, #T_b21b1_row1_col3, #T_b21b1_row2_col0, #T_b21b1_row3_col0, #T_b21b1_row4_col0, #T_b21b1_row5_col0, #T_b21b1_row5_col2, #T_b21b1_row6_col0, #T_b21b1_row6_col2, #T_b21b1_row6_col3, #T_b21b1_row7_col0, #T_b21b1_row7_col2, #T_b21b1_row8_col0, #T_b21b1_row8_col2, #T_b21b1_row9_col0, #T_b21b1_row9_col2, #T_b21b1_row10_col0, #T_b21b1_row11_col0, #T_b21b1_row11_col3, #T_b21b1_row12_col0, #T_b21b1_row13_col0, #T_b21b1_row14_col0, #T_b21b1_row15_col0, #T_b21b1_row16_col0, #T_b21b1_row16_col3, #T_b21b1_row17_col0, #T_b21b1_row18_col0, #T_b21b1_row19_col0, #T_b21b1_row20_col0, #T_b21b1_row21_col0, #T_b21b1_row21_col3, #T_b21b1_row22_col0, #T_b21b1_row23_col0, #T_b21b1_row24_col0, #T_b21b1_row25_col0, #T_b21b1_row26_col0, #T_b21b1_row26_col3, #T_b21b1_row27_col0, #T_b21b1_row28_col0, #T_b21b1_row29_col0, #T_b21b1_row30_col0, #T_b21b1_row31_col0, #T_b21b1_row31_col3, #T_b21b1_row32_col0, #T_b21b1_row33_col0, #T_b21b1_row34_col0, #T_b21b1_row35_col0, #T_b21b1_row35_col2, #T_b21b1_row36_col0, #T_b21b1_row36_col2, #T_b21b1_row36_col3, #T_b21b1_row37_col0, #T_b21b1_row37_col2, #T_b21b1_row38_col0, #T_b21b1_row38_col2, #T_b21b1_row39_col0, #T_b21b1_row39_col2, #T_b21b1_row40_col0, #T_b21b1_row41_col0, #T_b21b1_row41_col3, #T_b21b1_row42_col0, #T_b21b1_row43_col0, #T_b21b1_row44_col0, #T_b21b1_row45_col0, #T_b21b1_row46_col0, #T_b21b1_row46_col3, #T_b21b1_row47_col0, #T_b21b1_row48_col0, #T_b21b1_row49_col0, #T_b21b1_row50_col0, #T_b21b1_row51_col0, #T_b21b1_row51_col3, #T_b21b1_row52_col0, #T_b21b1_row53_col0, #T_b21b1_row54_col0, #T_b21b1_row55_col0, #T_b21b1_row56_col0, #T_b21b1_row56_col3, #T_b21b1_row57_col0, #T_b21b1_row58_col0, #T_b21b1_row59_col0, #T_b21b1_row60_col0, #T_b21b1_row61_col0, #T_b21b1_row61_col3, #T_b21b1_row62_col0, #T_b21b1_row63_col0, #T_b21b1_row64_col0, #T_b21b1_row65_col0, #T_b21b1_row65_col2, #T_b21b1_row66_col0, #T_b21b1_row66_col2, #T_b21b1_row66_col3, #T_b21b1_row67_col0, #T_b21b1_row67_col2, #T_b21b1_row68_col0, #T_b21b1_row68_col2, #T_b21b1_row69_col0, #T_b21b1_row69_col2, #T_b21b1_row70_col0, #T_b21b1_row71_col0, #T_b21b1_row71_col3, #T_b21b1_row72_col0, #T_b21b1_row73_col0, #T_b21b1_row74_col0, #T_b21b1_row75_col0, #T_b21b1_row76_col0, #T_b21b1_row76_col3, #T_b21b1_row77_col0, #T_b21b1_row78_col0, #T_b21b1_row79_col0, #T_b21b1_row80_col0, #T_b21b1_row81_col0, #T_b21b1_row81_col3, #T_b21b1_row82_col0, #T_b21b1_row83_col0, #T_b21b1_row84_col0, #T_b21b1_row85_col0, #T_b21b1_row86_col0, #T_b21b1_row86_col3, #T_b21b1_row87_col0, #T_b21b1_row88_col0, #T_b21b1_row89_col0, #T_b21b1_row90_col0, #T_b21b1_row90_col1, #T_b21b1_row91_col0, #T_b21b1_row91_col1, #T_b21b1_row91_col3, #T_b21b1_row92_col0, #T_b21b1_row92_col1, #T_b21b1_row93_col0, #T_b21b1_row93_col1, #T_b21b1_row94_col0, #T_b21b1_row94_col1, #T_b21b1_row95_col0, #T_b21b1_row95_col1, #T_b21b1_row95_col2, #T_b21b1_row95_col7, #T_b21b1_row96_col0, #T_b21b1_row96_col1, #T_b21b1_row96_col2, #T_b21b1_row96_col3, #T_b21b1_row96_col4, #T_b21b1_row96_col5, #T_b21b1_row96_col6, #T_b21b1_row96_col7, #T_b21b1_row96_col8, #T_b21b1_row96_col9, #T_b21b1_row96_col10, #T_b21b1_row96_col11, #T_b21b1_row96_col12, #T_b21b1_row96_col13, #T_b21b1_row96_col14, #T_b21b1_row96_col15, #T_b21b1_row96_col16, #T_b21b1_row96_col17, #T_b21b1_row97_col0, #T_b21b1_row97_col1, #T_b21b1_row97_col2, #T_b21b1_row97_col7, #T_b21b1_row98_col0, #T_b21b1_row98_col1, #T_b21b1_row98_col2, #T_b21b1_row98_col7, #T_b21b1_row99_col0, #T_b21b1_row99_col1, #T_b21b1_row99_col2, #T_b21b1_row99_col7, #T_b21b1_row100_col0, #T_b21b1_row100_col1, #T_b21b1_row101_col0, #T_b21b1_row101_col1, #T_b21b1_row101_col3, #T_b21b1_row102_col0, #T_b21b1_row102_col1, #T_b21b1_row103_col0, #T_b21b1_row103_col1, #T_b21b1_row104_col0, #T_b21b1_row104_col1, #T_b21b1_row105_col0, #T_b21b1_row105_col1, #T_b21b1_row106_col0, #T_b21b1_row106_col1, #T_b21b1_row106_col3, #T_b21b1_row107_col0, #T_b21b1_row107_col1, #T_b21b1_row108_col0, #T_b21b1_row108_col1, #T_b21b1_row109_col0, #T_b21b1_row109_col ...
#   font-weight: bold;
# }
# #T_b21b1_row3_col13, #T_b21b1_row30_col10, #T_b21b1_row30_col11, #T_b21b1_row30_col12, #T_b21b1_row30_col14, #T_b21b1_row30_col15, #T_b21b1_row30_col16, #T_b21b1_row30_col17 {
#   background: yellow;
# }
# #T_b21b1_row21_col6, #T_b21b1_row65_col7, #T_b21b1_row66_col7, #T_b21b1_row67_col7, #T_b21b1_row68_col7, #T_b21b1_row69_col7, #T_b21b1_row83_col4, #T_b21b1_row83_col5, #T_b21b1_row83_col8, #T_b21b1_row83_col9 {
#   background-color: lightgreen;
# }
# #T_b21b1_row96_col18 {
#   background-color: lightblue;
#   font-weight: bold;
# }
# </style>
# <table id="T_b21b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b21b1_level0_col0" class="col_heading level0 col0" >base_estimator</th>
#       <th id="T_b21b1_level0_col1" class="col_heading level0 col1" >param</th>
#       <th id="T_b21b1_level0_col2" class="col_heading level0 col2" >Bias_Mitigation</th>
#       <th id="T_b21b1_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_b21b1_level0_col4" class="col_heading level0 col4" >avg_acc_score</th>
#       <th id="T_b21b1_level0_col5" class="col_heading level0 col5" >avg_bacc_score</th>
#       <th id="T_b21b1_level0_col6" class="col_heading level0 col6" >avg_f1_score</th>
#       <th id="T_b21b1_level0_col7" class="col_heading level0 col7" >avg_auc_score</th>
#       <th id="T_b21b1_level0_col8" class="col_heading level0 col8" >avg_mcc_score</th>
#       <th id="T_b21b1_level0_col9" class="col_heading level0 col9" >avg_norm_mcc_score</th>
#       <th id="T_b21b1_level0_col10" class="col_heading level0 col10" >avg_spd_score</th>
#       <th id="T_b21b1_level0_col11" class="col_heading level0 col11" >avg_aod_score</th>
#       <th id="T_b21b1_level0_col12" class="col_heading level0 col12" >avg_eod_score</th>
#       <th id="T_b21b1_level0_col13" class="col_heading level0 col13" >avg_ford_score</th>
#       <th id="T_b21b1_level0_col14" class="col_heading level0 col14" >avg_ppvd_score</th>
#       <th id="T_b21b1_level0_col15" class="col_heading level0 col15" >avg_(1-consistency_score)</th>
#       <th id="T_b21b1_level0_col16" class="col_heading level0 col16" >avg_gei_score</th>
#       <th id="T_b21b1_level0_col17" class="col_heading level0 col17" >avg_ti_score</th>
#       <th id="T_b21b1_level0_col18" class="col_heading level0 col18" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b21b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b21b1_row0_col0" class="data row0 col0" >TabTrans</td>
#       <td id="T_b21b1_row0_col1" class="data row0 col1" >{'epochs': 20, 'learing_rate': 0.0001}</td>
#       <td id="T_b21b1_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_b21b1_row0_col3" class="data row0 col3" >0.300000</td>
#       <td id="T_b21b1_row0_col4" class="data row0 col4" >0.553008</td>
#       <td id="T_b21b1_row0_col5" class="data row0 col5" >0.521394</td>
#       <td id="T_b21b1_row0_col6" class="data row0 col6" >0.702557</td>
#       <td id="T_b21b1_row0_col7" class="data row0 col7" >0.649415</td>
#       <td id="T_b21b1_row0_col8" class="data row0 col8" >0.108178</td>
#       <td id="T_b21b1_row0_col9" class="data row0 col9" >0.554089</td>
#       <td id="T_b21b1_row0_col10" class="data row0 col10" >0.031325</td>
#       <td id="T_b21b1_row0_col11" class="data row0 col11" >0.028844</td>
#       <td id="T_b21b1_row0_col12" class="data row0 col12" >0.046125</td>
#       <td id="T_b21b1_row0_col13" class="data row0 col13" >0.111003</td>
#       <td id="T_b21b1_row0_col14" cl
